# %%
'''
In this file we train SketchVAE + SketchInpainter
'''
import torch
import os
import numpy as np
from torch import optim
from torch.nn import functional as F
from SketchVAE.sketchvae import SketchVAE
from torch import optim
from torch.utils.data import Dataset, DataLoader, TensorDataset
from torch.distributions import Normal
from SketchNet.sketchnet import SketchNet
from utils.helpers import *
import time
###############################
# initial parameters
s_dir = "" # folder_address
zp_dims = 128
zr_dims = 128
pf_dims = 512
gen_dims = 1024
combine_dims = 512
combine_head = 4
combine_num = 4
pf_num = 2
inpaint_len = 4
total_len = 16
batch_size = 32
n_epochs = 100
save_path = "model_backup"
# set here to config your save_period (2 i.e. save the model every 2 epochs)
save_period = 5

"""
The same to 3-2
"""
data_path = [
    "data/irish-dis-measure-vae-train-whole.npy",
    "data/irish-dis-measure-vae-validate-whole.npy",
    "data/irish-dis-measure-vae-test-whole.npy"
]
lr = 1e-4
decay = 0.9999
##############################
##############  for vae init ##############
vae_hidden_dims = 1024
vae_zp_dims = 128
vae_zr_dims = 128
vae_beta = 0.1
vae_input_dims = 130
vae_pitch_dims = 129
vae_rhythm_dims = 3
vae_seq_len = 6 * 4
vae_beat_num = 4
vae_tick_num = 6
############################

# %%
# input data dis-measure-vae
def processed_data_tensor(data):
    print("processed data:")
    gd = [] 
    px = []
    rx = []
    len_x = []
    nrx = []
    total = 0
    for i, d in enumerate(data):
        gd.append([list(dd[0]) for dd in d])
        px.append([list(dd[1]) for dd in d])
        rx.append([list(dd[2]) for dd in d])
        len_x.append([dd[3] for dd in d])
        if len(gd[-1][-1]) != vae_seq_len:
            gd[-1][-1].extend([128] * (vae_seq_len - len(gd[-1][-1])))
            px[-1][-1].extend([128] * (vae_seq_len - len(px[-1][-1])))
            rx[-1][-1].extend([2] * (vae_seq_len - len(rx[-1][-1])))
    for i,d in enumerate(len_x):
        for j,dd in enumerate(d):
            if len_x[i][j] == 0:
                gd[i][j][0] = 60
                px[i][j][0] = 60
                rx[i][j][0] = 1
                len_x[i][j] = 1
                total += 1
    gd = np.array(gd)
    px = np.array(px)
    rx = np.array(rx)
    len_x = np.array(len_x)
    for d in rx:
        nnrx = []
        for dd in d:
            temp = np.zeros((vae_seq_len, vae_rhythm_dims))
            lins = np.arange(0, len(dd))
            temp[lins, dd - 1] = 1
            nnrx.append(temp)
        nrx.append(nnrx)
    nrx = np.array(nrx)
    gd = torch.from_numpy(gd).long()
    px = torch.from_numpy(px).long()
    rx = torch.from_numpy(rx).float()
    len_x = torch.from_numpy(len_x).long()
    nrx = torch.from_numpy(nrx).float()
    print("processed finish! zeros:", total)
    print(gd.size(),px.size(),rx.size(),len_x.size(),nrx.size())
    return TensorDataset(px, rx, len_x, nrx, gd)

train_set = np.load(os.path.join(s_dir,data_path[0]),allow_pickle = True)
train_loader = DataLoader(
    dataset = processed_data_tensor(train_set),
    batch_size = batch_size, 
    shuffle = True, 
    num_workers = 8, 
    pin_memory = True, 
    drop_last = True
)

validate_set = np.load(os.path.join(s_dir,data_path[1]),allow_pickle = True)
validate_loader = DataLoader(
    dataset = processed_data_tensor(validate_set),
    batch_size = batch_size, 
    shuffle = False, 
    num_workers = 8, 
    pin_memory = True, 
    drop_last = True
)
validate_data = []
for i,d in enumerate(validate_loader):
    validate_data.append(d)
print(len(validate_data))
# Out:
# processed data:
# processed finish! zeros: 256
# torch.Size([39798, 16, 24]) torch.Size([39798, 16, 24]) torch.Size([39798, 16, 24]) torch.Size([39798, 16]) torch.Size([39798, 16, 24, 3])
# processed data:
# processed finish! zeros: 1
# torch.Size([2927, 16, 24]) torch.Size([2927, 16, 24]) torch.Size([2927, 16, 24]) torch.Size([2927, 16]) torch.Size([2927, 16, 24, 3])
# 91

# %%
# load VAE model
vae_model = SketchVAE(
    vae_input_dims, vae_pitch_dims, vae_rhythm_dims, vae_hidden_dims, 
    vae_zp_dims, vae_zr_dims, vae_seq_len, vae_beat_num, vae_tick_num, 4000)

# sketchvae-param.pt is your saved sketchVAE model
dic = torch.load(os.path.join(s_dir, save_path, "sketchvae-loss_0.04435703124001108_acc_0.9970518388541095_epoch_22_it_147928.pt"))

for name in list(dic.keys()):
    dic[name.replace('module.', '')] = dic.pop(name)
vae_model.load_state_dict(dic)

if torch.cuda.is_available():
    print('Using: ', torch.cuda.get_device_name(torch.cuda.current_device()))
    vae_model.cuda()
else:
    print('Using: CPU')
vae_model.eval()
print(vae_model.training)
# Out:
# Using:  NVIDIA GeForce RTX 2080 Ti
# False

# %%
# import model
model = SketchNet(
    zp_dims, zr_dims, 
    pf_dims, gen_dims, combine_dims,
    pf_num, combine_num, combine_head,
    inpaint_len, total_len, 
    vae_model, True
)
optimizer = optim.Adam(filter(lambda p: p.requires_grad, model.parameters()),lr=lr)
if torch.cuda.is_available():
    print('Using: ', torch.cuda.get_device_name(torch.cuda.current_device()))
    model.cuda()
else:
    print('Using: CPU')
print(model)
# Out:
# Using:  NVIDIA GeForce RTX 2080 Ti
# SketchNet(
#   (past_p_gru): GRU(128, 512, num_layers=2, batch_first=True, dropout=0.5, bidirectional=True)
#   (past_r_gru): GRU(128, 512, num_layers=2, batch_first=True, dropout=0.5, bidirectional=True)
#   (future_p_gru): GRU(128, 512, num_layers=2, batch_first=True, dropout=0.5, bidirectional=True)
#   (future_r_gru): GRU(128, 512, num_layers=2, batch_first=True, dropout=0.5, bidirectional=True)
#   (gen_p_gru): GRU(128, 1024, num_layers=2, batch_first=True, dropout=0.5, bidirectional=True)
#   (gen_r_gru): GRU(128, 1024, num_layers=2, batch_first=True, dropout=0.5, bidirectional=True)
#   (gen_p_out): Linear(in_features=2048, out_features=128, bias=True)
#   (gen_r_out): Linear(in_features=2048, out_features=128, bias=True)
#   (combine_in): Linear(in_features=256, out_features=512, bias=True)
#   (combine_posenc): PositionalEncoding()
#   (combine_dropout): Dropout(p=0.1, inplace=False)
#   (combine_nn): ModuleList(
#     (0): CombineLayer(
#       (slf_attn): MultiHeadAttention(
#         (w_qs): Linear(in_features=512, out_features=512, bias=False)
#         (w_ks): Linear(in_features=512, out_features=512, bias=False)
#         (w_vs): Linear(in_features=512, out_features=512, bias=False)
#         (fc): Linear(in_features=512, out_features=512, bias=False)
#         (attention): ScaledDotProductAttention(
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (dropout): Dropout(p=0.1, inplace=False)
#         (layer_norm): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#       )
#       (pos_ffn): PositionwiseFeedForward(
#         (w_1): Linear(in_features=512, out_features=2048, bias=True)
#         (w_2): Linear(in_features=2048, out_features=512, bias=True)
#         (layer_norm): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#     )
#     (1): CombineLayer(
#       (slf_attn): MultiHeadAttention(
#         (w_qs): Linear(in_features=512, out_features=512, bias=False)
#         (w_ks): Linear(in_features=512, out_features=512, bias=False)
#         (w_vs): Linear(in_features=512, out_features=512, bias=False)
#         (fc): Linear(in_features=512, out_features=512, bias=False)
#         (attention): ScaledDotProductAttention(
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (dropout): Dropout(p=0.1, inplace=False)
#         (layer_norm): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#       )
#       (pos_ffn): PositionwiseFeedForward(
#         (w_1): Linear(in_features=512, out_features=2048, bias=True)
#         (w_2): Linear(in_features=2048, out_features=512, bias=True)
#         (layer_norm): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#     )
#     (2): CombineLayer(
#       (slf_attn): MultiHeadAttention(
#         (w_qs): Linear(in_features=512, out_features=512, bias=False)
#         (w_ks): Linear(in_features=512, out_features=512, bias=False)
#         (w_vs): Linear(in_features=512, out_features=512, bias=False)
#         (fc): Linear(in_features=512, out_features=512, bias=False)
#         (attention): ScaledDotProductAttention(
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (dropout): Dropout(p=0.1, inplace=False)
#         (layer_norm): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#       )
#       (pos_ffn): PositionwiseFeedForward(
#         (w_1): Linear(in_features=512, out_features=2048, bias=True)
#         (w_2): Linear(in_features=2048, out_features=512, bias=True)
#         (layer_norm): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#     )
#     (3): CombineLayer(
#       (slf_attn): MultiHeadAttention(
#         (w_qs): Linear(in_features=512, out_features=512, bias=False)
#         (w_ks): Linear(in_features=512, out_features=512, bias=False)
#         (w_vs): Linear(in_features=512, out_features=512, bias=False)
#         (fc): Linear(in_features=512, out_features=512, bias=False)
#         (attention): ScaledDotProductAttention(
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (dropout): Dropout(p=0.1, inplace=False)
#         (layer_norm): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#       )
#       (pos_ffn): PositionwiseFeedForward(
#         (w_1): Linear(in_features=512, out_features=2048, bias=True)
#         (w_2): Linear(in_features=2048, out_features=512, bias=True)
#         (layer_norm): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#     )
#   )
#   (combine_norm): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#   (combine_out): Linear(in_features=512, out_features=256, bias=True)
#   (vae_model): SketchVAE(
#     (p_embedding): Embedding(130, 10)
#     (p_encoder_gru): GRU(10, 1024, num_layers=2, batch_first=True, dropout=0.2, bidirectional=True)
#     (p_linear_mu): Linear(in_features=4096, out_features=128, bias=True)
#     (p_linear_var): Linear(in_features=4096, out_features=128, bias=True)
#     (r_encoder_gru): GRU(3, 1024, num_layers=2, batch_first=True, dropout=0.2, bidirectional=True)
#     (r_linear_mu): Linear(in_features=4096, out_features=128, bias=True)
#     (r_linear_var): Linear(in_features=4096, out_features=128, bias=True)
#     (z_to_beat_hidden): Sequential(
#       (0): Linear(in_features=256, out_features=2048, bias=True)
#       (1): SELU()
#     )
#     (beat_gru): GRU(1, 1024, num_layers=2, batch_first=True, dropout=0.2)
#     (beat_to_tick_hidden): Sequential(
#       (0): Linear(in_features=1024, out_features=2048, bias=True)
#       (1): SELU()
#     )
#     (beat_to_tick_input): Sequential(
#       (0): Linear(in_features=1024, out_features=1024, bias=True)
#       (1): SELU()
#     )
#     (d_embedding): Embedding(130, 10)
#     (tick_gru): GRU(1034, 1024, num_layers=2, batch_first=True, dropout=0.2)
#     (tick_to_note): Sequential(
#       (0): Linear(in_features=1024, out_features=130, bias=True)
#       (1): ReLU()
#     )
#   )
# )

# %%
def process_raw_x(raw_x, n_past, n_inpaint, n_future):
    raw_px, raw_rx, raw_len_x, raw_nrx, raw_gd = raw_x
    past_px = raw_px[:,:n_past,:]
    inpaint_px = raw_px[:,n_past:n_past + n_inpaint,:]
    future_px = raw_px[:,n_future:,:]
    past_rx = raw_rx[:,:n_past,:]
    inpaint_rx = raw_rx[:,n_past:n_past + n_inpaint,:]
    future_rx = raw_rx[:,n_future:,:]
    past_len_x = raw_len_x[:,:n_past]
    inpaint_len_x = raw_len_x[:,n_past:n_past + n_inpaint]
    future_len_x = raw_len_x[:,n_future:]
    past_nrx = raw_nrx[:,:n_past,:]
    inpaint_nrx = raw_nrx[:,n_past:n_past + n_inpaint,:]
    future_nrx = raw_nrx[:,n_future:,:]
    past_gd = raw_gd[:,:n_past,:]
    inpaint_gd = raw_gd[:,n_past:n_past + n_inpaint,:]
    future_gd = raw_gd[:,n_future:,:]
    re = [
        past_px, past_rx, past_len_x, past_nrx, past_gd,
        inpaint_px, inpaint_rx, inpaint_len_x, inpaint_nrx, inpaint_gd,
        future_px, future_rx, future_len_x, future_nrx, future_gd,
    ]
    return re
def get_acc(recon, gd):
    recon = recon.cpu().detach().numpy()
    gd = gd.cpu().detach().numpy()
    return np.sum(recon == gd) / recon.size

model.set_stage = "inpainting"
device = torch.device(torch.cuda.current_device())
losses = []
step = 0
n_past = 6
n_future = 10
n_inpaint = 4
iteration = 0
# save_period = 200
print(vae_model.training)
for epoch in range(n_epochs):
    model.train()
    print("epoch: %d\n__________________________________________" % (epoch), flush = True)
    mean_loss = 0.0
    mean_acc = 0.0
    v_mean_loss = 0.0
    v_mean_acc = 0.0
    total = 0
    for i,tr_data in enumerate(train_loader):
        model.train()
#         print("begin_time", time.process_time())
        j = i % len(validate_data)
        raw_x = process_raw_x(tr_data, n_past, n_inpaint, n_future)
        for k in range(len(raw_x)):
            raw_x[k] = raw_x[k].to(device = device,non_blocking = True)
        past_px, past_rx, past_len_x, past_nrx, past_gd, \
        inpaint_px, inpaint_rx, inpaint_len_x, inpaint_nrx, inpaint_gd,\
        future_px, future_rx, future_len_x, future_nrx, future_gd = raw_x
        inpaint_gd_whole = inpaint_gd.contiguous().view(-1)
        past_x = [past_px, past_rx, past_len_x, past_nrx, past_gd]
        inpaint_x = [inpaint_px, inpaint_rx, inpaint_len_x, inpaint_nrx, inpaint_gd]
        future_x = [future_px, future_rx, future_len_x, future_nrx, future_gd]
        
        # validate
        v_raw_x = process_raw_x(validate_data[j], n_past, n_inpaint, n_future)
        for k in range(len(v_raw_x)):
            v_raw_x[k] = v_raw_x[k].to(device = device,non_blocking = True)
        v_past_px, v_past_rx, v_past_len_x, v_past_nrx, v_past_gd, \
        v_inpaint_px, v_inpaint_rx, v_inpaint_len_x, v_inpaint_nrx, v_inpaint_gd,\
        v_future_px, v_future_rx, v_future_len_x, v_future_nrx, v_future_gd = v_raw_x
        v_inpaint_gd_whole = v_inpaint_gd.contiguous().view(-1)
        v_past_x = [v_past_px, v_past_rx, v_past_len_x, v_past_nrx, v_past_gd]
        v_inpaint_x = [v_inpaint_px, v_inpaint_rx, v_inpaint_len_x, v_inpaint_nrx, v_inpaint_gd]
        v_future_x = [v_future_px, v_future_rx, v_future_len_x, v_future_nrx, v_future_gd]
        
        optimizer.zero_grad()
        
        recon_x, iteration, use_teacher, stage = model(past_x, future_x, inpaint_x)

        loss = F.cross_entropy(recon_x.view(-1, recon_x.size(-1)), inpaint_gd_whole, reduction = "mean") 
        acc = get_acc(recon_x.view(-1, recon_x.size(-1)).argmax(-1), inpaint_gd_whole)
        loss.backward()
        optimizer.step()
   
        total += 1
        mean_loss += loss.item()
        mean_acc += acc
  
        model.eval()
        with torch.no_grad():
            v_recon_x, _,_,_ = model(v_past_x, v_future_x, v_inpaint_x)
            v_loss = F.cross_entropy(v_recon_x.view(-1, v_recon_x.size(-1)), v_inpaint_gd_whole, reduction = "mean") 
            v_acc = get_acc(v_recon_x.view(-1, v_recon_x.size(-1)).argmax(-1), v_inpaint_gd_whole)
            v_mean_loss += v_loss.item()
            v_mean_acc += v_acc
        print("batch %d loss: %.5f acc: %.5f | v_loss: %.5f v_acc: %.5f |  iteration: %d teacher: %d stage: %s" \
              % (i,loss.item(), acc, v_loss.item(), v_acc, iteration, use_teacher, stage),flush = True)
    mean_loss /= total
    mean_acc /= total
    v_mean_loss /= total
    v_mean_acc /= total
    print("epoch %d loss: %.5f acc: %.5f | v_loss: %.5f v_acc: %.5f "  % (epoch,mean_loss, mean_acc, v_mean_loss, v_mean_acc),flush = True)
    losses.append([mean_loss, v_mean_loss])
    if (epoch + 1) % save_period == 0:
        filename = "sketchNet-stage-1" + 'loss_' + str(v_mean_loss) + "_acc_" + str(v_mean_acc) + "_epoch_" + str(epoch+1) + '_it_' + str(iteration) + ".pt"
        torch.save(model.cpu().state_dict(),os.path.join(s_dir, save_path, filename))
        model.cuda()
    np.save(os.path.join(s_dir,"sketchnet_stage1_log.npy"),losses)
# Out:
# False
# epoch: 0
# __________________________________________
# batch 0 loss: 3.75902 acc: 0.65690 | v_loss: 3.14532 v_acc: 0.67285 |  iteration: 1 teacher: 0 stage: inpainting
# batch 1 loss: 3.28246 acc: 0.66960 | v_loss: 2.91910 v_acc: 0.67578 |  iteration: 2 teacher: 0 stage: inpainting
# batch 2 loss: 3.41878 acc: 0.67611 | v_loss: 3.60060 v_acc: 0.66504 |  iteration: 3 teacher: 1 stage: inpainting
# batch 3 loss: 3.52040 acc: 0.67253 | v_loss: 3.01697 v_acc: 0.67773 |  iteration: 4 teacher: 1 stage: inpainting
# batch 4 loss: 3.46636 acc: 0.67415 | v_loss: 2.90559 v_acc: 0.68327 |  iteration: 5 teacher: 1 stage: inpainting
# batch 5 loss: 3.31532 acc: 0.67578 | v_loss: 2.55015 v_acc: 0.68750 |  iteration: 6 teacher: 0 stage: inpainting
# batch 6 loss: 2.96003 acc: 0.68620 | v_loss: 2.92778 v_acc: 0.68099 |  iteration: 7 teacher: 0 stage: inpainting
# batch 7 loss: 2.80628 acc: 0.69629 | v_loss: 3.52929 v_acc: 0.65918 |  iteration: 8 teacher: 1 stage: inpainting
# batch 8 loss: 3.07591 acc: 0.69076 | v_loss: 2.67303 v_acc: 0.68490 |  iteration: 9 teacher: 0 stage: inpainting
# batch 9 loss: 3.35457 acc: 0.67773 | v_loss: 2.49897 v_acc: 0.69238 |  iteration: 10 teacher: 0 stage: inpainting
# batch 10 loss: 3.13139 acc: 0.68978 | v_loss: 2.88201 v_acc: 0.69108 |  iteration: 11 teacher: 1 stage: inpainting
# batch 11 loss: 3.20820 acc: 0.69694 | v_loss: 2.50044 v_acc: 0.69759 |  iteration: 12 teacher: 1 stage: inpainting
# batch 12 loss: 2.94446 acc: 0.68197 | v_loss: 2.51450 v_acc: 0.71094 |  iteration: 13 teacher: 0 stage: inpainting
# batch 13 loss: 3.23281 acc: 0.68880 | v_loss: 2.52440 v_acc: 0.70247 |  iteration: 14 teacher: 1 stage: inpainting
# batch 14 loss: 2.98789 acc: 0.67611 | v_loss: 2.58942 v_acc: 0.69727 |  iteration: 15 teacher: 0 stage: inpainting
# batch 15 loss: 2.94566 acc: 0.70182 | v_loss: 2.65003 v_acc: 0.70801 |  iteration: 16 teacher: 1 stage: inpainting
# batch 16 loss: 2.81958 acc: 0.68652 | v_loss: 2.68382 v_acc: 0.69531 |  iteration: 17 teacher: 0 stage: inpainting
# batch 17 loss: 2.82569 acc: 0.69401 | v_loss: 2.55962 v_acc: 0.69303 |  iteration: 18 teacher: 1 stage: inpainting
# batch 18 loss: 2.83383 acc: 0.69368 | v_loss: 2.55320 v_acc: 0.71159 |  iteration: 19 teacher: 1 stage: inpainting
# batch 19 loss: 2.69461 acc: 0.69629 | v_loss: 2.96049 v_acc: 0.68034 |  iteration: 20 teacher: 1 stage: inpainting
# batch 20 loss: 2.83552 acc: 0.69727 | v_loss: 2.58332 v_acc: 0.69629 |  iteration: 21 teacher: 1 stage: inpainting
# batch 21 loss: 2.84758 acc: 0.69857 | v_loss: 2.29321 v_acc: 0.71419 |  iteration: 22 teacher: 1 stage: inpainting
# batch 22 loss: 2.75084 acc: 0.68555 | v_loss: 2.65646 v_acc: 0.68945 |  iteration: 23 teacher: 0 stage: inpainting
# batch 23 loss: 2.63795 acc: 0.69792 | v_loss: 2.56665 v_acc: 0.68945 |  iteration: 24 teacher: 1 stage: inpainting
# batch 24 loss: 2.67785 acc: 0.69694 | v_loss: 2.78119 v_acc: 0.67220 |  iteration: 25 teacher: 1 stage: inpainting
# batch 25 loss: 2.72326 acc: 0.68815 | v_loss: 2.54465 v_acc: 0.68555 |  iteration: 26 teacher: 0 stage: inpainting
# batch 26 loss: 2.56018 acc: 0.68555 | v_loss: 2.71094 v_acc: 0.67513 |  iteration: 27 teacher: 0 stage: inpainting
# batch 27 loss: 2.64104 acc: 0.67578 | v_loss: 2.44346 v_acc: 0.68164 |  iteration: 28 teacher: 0 stage: inpainting
# batch 28 loss: 2.59458 acc: 0.67773 | v_loss: 2.82402 v_acc: 0.66113 |  iteration: 29 teacher: 1 stage: inpainting
# batch 29 loss: 2.58026 acc: 0.67611 | v_loss: 2.15457 v_acc: 0.68945 |  iteration: 30 teacher: 0 stage: inpainting
# batch 30 loss: 2.35853 acc: 0.68783 | v_loss: 2.42140 v_acc: 0.68262 |  iteration: 31 teacher: 0 stage: inpainting
# batch 31 loss: 2.73139 acc: 0.66667 | v_loss: 2.19416 v_acc: 0.68978 |  iteration: 32 teacher: 1 stage: inpainting
# batch 32 loss: 2.53003 acc: 0.67676 | v_loss: 2.63393 v_acc: 0.67253 |  iteration: 33 teacher: 0 stage: inpainting
# batch 33 loss: 2.59880 acc: 0.68522 | v_loss: 2.10059 v_acc: 0.67969 |  iteration: 34 teacher: 1 stage: inpainting
# batch 34 loss: 2.61571 acc: 0.68880 | v_loss: 2.62124 v_acc: 0.64062 |  iteration: 35 teacher: 1 stage: inpainting
# batch 35 loss: 2.50645 acc: 0.66992 | v_loss: 2.25690 v_acc: 0.68099 |  iteration: 36 teacher: 0 stage: inpainting
# batch 36 loss: 2.39618 acc: 0.69010 | v_loss: 2.53848 v_acc: 0.64616 |  iteration: 37 teacher: 1 stage: inpainting
# batch 37 loss: 2.32712 acc: 0.67773 | v_loss: 2.68838 v_acc: 0.63249 |  iteration: 38 teacher: 0 stage: inpainting
# batch 38 loss: 2.35432 acc: 0.67643 | v_loss: 2.28227 v_acc: 0.67350 |  iteration: 39 teacher: 0 stage: inpainting
# batch 39 loss: 2.36749 acc: 0.67415 | v_loss: 2.08932 v_acc: 0.68783 |  iteration: 40 teacher: 0 stage: inpainting
# batch 40 loss: 2.52130 acc: 0.67057 | v_loss: 2.06325 v_acc: 0.68555 |  iteration: 41 teacher: 1 stage: inpainting
# batch 41 loss: 2.33092 acc: 0.67253 | v_loss: 2.26386 v_acc: 0.67025 |  iteration: 42 teacher: 0 stage: inpainting
# batch 42 loss: 2.52146 acc: 0.67936 | v_loss: 2.12381 v_acc: 0.68424 |  iteration: 43 teacher: 1 stage: inpainting
# batch 43 loss: 2.39653 acc: 0.69010 | v_loss: 2.30431 v_acc: 0.65495 |  iteration: 44 teacher: 1 stage: inpainting
# batch 44 loss: 2.42244 acc: 0.66243 | v_loss: 2.20981 v_acc: 0.67480 |  iteration: 45 teacher: 0 stage: inpainting
# batch 45 loss: 2.24748 acc: 0.67806 | v_loss: 2.00611 v_acc: 0.68490 |  iteration: 46 teacher: 0 stage: inpainting
# batch 46 loss: 2.29835 acc: 0.65951 | v_loss: 2.03462 v_acc: 0.67415 |  iteration: 47 teacher: 0 stage: inpainting
# batch 47 loss: 2.25507 acc: 0.66211 | v_loss: 2.06210 v_acc: 0.66341 |  iteration: 48 teacher: 0 stage: inpainting
# batch 48 loss: 2.32698 acc: 0.67806 | v_loss: 2.12489 v_acc: 0.64193 |  iteration: 49 teacher: 1 stage: inpainting
# batch 49 loss: 2.24951 acc: 0.64193 | v_loss: 2.07920 v_acc: 0.65267 |  iteration: 50 teacher: 0 stage: inpainting
# batch 50 loss: 2.19402 acc: 0.63802 | v_loss: 1.85860 v_acc: 0.66862 |  iteration: 51 teacher: 0 stage: inpainting
# batch 51 loss: 2.22392 acc: 0.68262 | v_loss: 2.00184 v_acc: 0.65234 |  iteration: 52 teacher: 1 stage: inpainting
# batch 52 loss: 2.19076 acc: 0.63151 | v_loss: 2.16577 v_acc: 0.63411 |  iteration: 53 teacher: 0 stage: inpainting
# batch 53 loss: 2.09295 acc: 0.68132 | v_loss: 2.06422 v_acc: 0.64290 |  iteration: 54 teacher: 1 stage: inpainting
# batch 54 loss: 2.13702 acc: 0.68555 | v_loss: 2.04643 v_acc: 0.63770 |  iteration: 55 teacher: 1 stage: inpainting
# batch 55 loss: 2.02627 acc: 0.65332 | v_loss: 2.05499 v_acc: 0.63932 |  iteration: 56 teacher: 0 stage: inpainting
# batch 56 loss: 2.05365 acc: 0.67741 | v_loss: 2.01055 v_acc: 0.66927 |  iteration: 57 teacher: 1 stage: inpainting
# batch 57 loss: 2.06974 acc: 0.68555 | v_loss: 2.13059 v_acc: 0.61882 |  iteration: 58 teacher: 1 stage: inpainting
# batch 58 loss: 2.24358 acc: 0.61849 | v_loss: 2.12602 v_acc: 0.61849 |  iteration: 59 teacher: 0 stage: inpainting
# batch 59 loss: 2.16931 acc: 0.63151 | v_loss: 1.88382 v_acc: 0.64714 |  iteration: 60 teacher: 0 stage: inpainting
# batch 60 loss: 2.14191 acc: 0.68457 | v_loss: 1.84295 v_acc: 0.66374 |  iteration: 61 teacher: 1 stage: inpainting
# batch 61 loss: 2.22726 acc: 0.64128 | v_loss: 1.76264 v_acc: 0.68001 |  iteration: 62 teacher: 0 stage: inpainting
# batch 62 loss: 2.15856 acc: 0.64323 | v_loss: 1.90347 v_acc: 0.64355 |  iteration: 63 teacher: 0 stage: inpainting
# batch 63 loss: 1.91913 acc: 0.67839 | v_loss: 1.96035 v_acc: 0.63086 |  iteration: 64 teacher: 1 stage: inpainting
# batch 64 loss: 1.89860 acc: 0.65723 | v_loss: 1.81347 v_acc: 0.67090 |  iteration: 65 teacher: 0 stage: inpainting
# batch 65 loss: 1.89592 acc: 0.69564 | v_loss: 2.07321 v_acc: 0.66211 |  iteration: 66 teacher: 1 stage: inpainting
# batch 66 loss: 1.96445 acc: 0.65495 | v_loss: 2.08513 v_acc: 0.63542 |  iteration: 67 teacher: 0 stage: inpainting
# batch 67 loss: 1.86665 acc: 0.66895 | v_loss: 1.91847 v_acc: 0.65820 |  iteration: 68 teacher: 0 stage: inpainting
# batch 68 loss: 1.88779 acc: 0.66406 | v_loss: 1.79197 v_acc: 0.67090 |  iteration: 69 teacher: 0 stage: inpainting
# batch 69 loss: 1.97515 acc: 0.67480 | v_loss: 1.80877 v_acc: 0.66536 |  iteration: 70 teacher: 1 stage: inpainting
# batch 70 loss: 2.03589 acc: 0.65788 | v_loss: 1.55367 v_acc: 0.70605 |  iteration: 71 teacher: 1 stage: inpainting
# batch 71 loss: 1.86250 acc: 0.67578 | v_loss: 1.71620 v_acc: 0.68555 |  iteration: 72 teacher: 1 stage: inpainting
# batch 72 loss: 1.87336 acc: 0.67806 | v_loss: 1.65458 v_acc: 0.68034 |  iteration: 73 teacher: 1 stage: inpainting
# batch 73 loss: 1.81671 acc: 0.68197 | v_loss: 1.79169 v_acc: 0.68945 |  iteration: 74 teacher: 0 stage: inpainting
# batch 74 loss: 1.80595 acc: 0.67480 | v_loss: 1.68973 v_acc: 0.67936 |  iteration: 75 teacher: 1 stage: inpainting
# batch 75 loss: 1.86683 acc: 0.67448 | v_loss: 1.73622 v_acc: 0.67513 |  iteration: 76 teacher: 0 stage: inpainting
# batch 76 loss: 1.84225 acc: 0.67936 | v_loss: 1.72310 v_acc: 0.69206 |  iteration: 77 teacher: 1 stage: inpainting
# batch 77 loss: 2.08290 acc: 0.65951 | v_loss: 1.67480 v_acc: 0.67611 |  iteration: 78 teacher: 0 stage: inpainting
# batch 78 loss: 1.75515 acc: 0.67611 | v_loss: 2.09783 v_acc: 0.66276 |  iteration: 79 teacher: 1 stage: inpainting
# batch 79 loss: 1.88845 acc: 0.66309 | v_loss: 1.63986 v_acc: 0.68815 |  iteration: 80 teacher: 1 stage: inpainting
# batch 80 loss: 1.84736 acc: 0.66602 | v_loss: 1.73391 v_acc: 0.67546 |  iteration: 81 teacher: 1 stage: inpainting
# batch 81 loss: 1.89016 acc: 0.66504 | v_loss: 1.64195 v_acc: 0.68620 |  iteration: 82 teacher: 0 stage: inpainting
# batch 82 loss: 1.74726 acc: 0.68327 | v_loss: 1.83406 v_acc: 0.66374 |  iteration: 83 teacher: 0 stage: inpainting
# batch 83 loss: 1.92517 acc: 0.65462 | v_loss: 1.58474 v_acc: 0.68978 |  iteration: 84 teacher: 1 stage: inpainting
# batch 84 loss: 1.88700 acc: 0.66569 | v_loss: 1.75797 v_acc: 0.68132 |  iteration: 85 teacher: 0 stage: inpainting
# batch 85 loss: 1.68280 acc: 0.66895 | v_loss: 1.64370 v_acc: 0.68522 |  iteration: 86 teacher: 1 stage: inpainting
# batch 86 loss: 1.70386 acc: 0.68197 | v_loss: 1.66467 v_acc: 0.69173 |  iteration: 87 teacher: 0 stage: inpainting
# batch 87 loss: 1.98532 acc: 0.65983 | v_loss: 1.72071 v_acc: 0.68294 |  iteration: 88 teacher: 0 stage: inpainting
# batch 88 loss: 1.93536 acc: 0.65820 | v_loss: 1.69541 v_acc: 0.68229 |  iteration: 89 teacher: 1 stage: inpainting
# batch 89 loss: 1.69604 acc: 0.68327 | v_loss: 1.79806 v_acc: 0.67155 |  iteration: 90 teacher: 0 stage: inpainting
# batch 90 loss: 1.74467 acc: 0.66862 | v_loss: 1.65074 v_acc: 0.67936 |  iteration: 91 teacher: 1 stage: inpainting
# batch 91 loss: 1.75678 acc: 0.68359 | v_loss: 1.73080 v_acc: 0.68783 |  iteration: 92 teacher: 0 stage: inpainting
# batch 92 loss: 1.79745 acc: 0.68164 | v_loss: 1.60278 v_acc: 0.68750 |  iteration: 93 teacher: 0 stage: inpainting
# batch 93 loss: 1.85520 acc: 0.67122 | v_loss: 1.67672 v_acc: 0.67936 |  iteration: 94 teacher: 0 stage: inpainting
# batch 94 loss: 1.65730 acc: 0.69108 | v_loss: 1.57955 v_acc: 0.69043 |  iteration: 95 teacher: 1 stage: inpainting
# batch 95 loss: 1.81637 acc: 0.67806 | v_loss: 1.57019 v_acc: 0.70378 |  iteration: 96 teacher: 1 stage: inpainting
# batch 96 loss: 1.67574 acc: 0.69531 | v_loss: 1.51014 v_acc: 0.69759 |  iteration: 97 teacher: 1 stage: inpainting
# batch 97 loss: 1.82941 acc: 0.66146 | v_loss: 1.75206 v_acc: 0.67253 |  iteration: 98 teacher: 1 stage: inpainting
# batch 98 loss: 1.93165 acc: 0.66732 | v_loss: 1.86186 v_acc: 0.66634 |  iteration: 99 teacher: 0 stage: inpainting
# batch 99 loss: 1.76415 acc: 0.67741 | v_loss: 1.61495 v_acc: 0.68783 |  iteration: 100 teacher: 0 stage: inpainting
# batch 100 loss: 1.71149 acc: 0.69108 | v_loss: 1.59379 v_acc: 0.68327 |  iteration: 101 teacher: 1 stage: inpainting
# batch 101 loss: 1.62295 acc: 0.69759 | v_loss: 1.55496 v_acc: 0.69564 |  iteration: 102 teacher: 1 stage: inpainting
# batch 102 loss: 1.92173 acc: 0.67415 | v_loss: 1.50791 v_acc: 0.68913 |  iteration: 103 teacher: 0 stage: inpainting
# batch 103 loss: 1.72782 acc: 0.69173 | v_loss: 1.45733 v_acc: 0.70671 |  iteration: 104 teacher: 1 stage: inpainting
# batch 104 loss: 1.59192 acc: 0.69596 | v_loss: 1.64348 v_acc: 0.67773 |  iteration: 105 teacher: 1 stage: inpainting
# batch 105 loss: 1.79275 acc: 0.66927 | v_loss: 1.35779 v_acc: 0.72201 |  iteration: 106 teacher: 1 stage: inpainting
# batch 106 loss: 1.64984 acc: 0.68750 | v_loss: 1.50801 v_acc: 0.68555 |  iteration: 107 teacher: 0 stage: inpainting
# batch 107 loss: 1.58149 acc: 0.69336 | v_loss: 1.60673 v_acc: 0.69010 |  iteration: 108 teacher: 1 stage: inpainting
# batch 108 loss: 1.60237 acc: 0.68945 | v_loss: 1.51756 v_acc: 0.70150 |  iteration: 109 teacher: 1 stage: inpainting
# batch 109 loss: 1.71907 acc: 0.68620 | v_loss: 1.54436 v_acc: 0.67904 |  iteration: 110 teacher: 0 stage: inpainting
# batch 110 loss: 1.78532 acc: 0.67220 | v_loss: 1.77582 v_acc: 0.66634 |  iteration: 111 teacher: 1 stage: inpainting
# batch 111 loss: 1.73114 acc: 0.68132 | v_loss: 1.55347 v_acc: 0.69206 |  iteration: 112 teacher: 1 stage: inpainting
# batch 112 loss: 1.70326 acc: 0.68913 | v_loss: 1.39437 v_acc: 0.72559 |  iteration: 113 teacher: 1 stage: inpainting
# batch 113 loss: 1.75925 acc: 0.67122 | v_loss: 1.59824 v_acc: 0.68685 |  iteration: 114 teacher: 0 stage: inpainting
# batch 114 loss: 1.70376 acc: 0.68685 | v_loss: 1.58655 v_acc: 0.69727 |  iteration: 115 teacher: 1 stage: inpainting
# batch 115 loss: 1.70422 acc: 0.67676 | v_loss: 1.62054 v_acc: 0.68848 |  iteration: 116 teacher: 0 stage: inpainting
# batch 116 loss: 1.69700 acc: 0.68392 | v_loss: 1.53666 v_acc: 0.68848 |  iteration: 117 teacher: 0 stage: inpainting
# batch 117 loss: 1.58368 acc: 0.69173 | v_loss: 1.53130 v_acc: 0.69661 |  iteration: 118 teacher: 1 stage: inpainting
# batch 118 loss: 1.57577 acc: 0.69661 | v_loss: 1.63296 v_acc: 0.67676 |  iteration: 119 teacher: 1 stage: inpainting
# batch 119 loss: 1.68417 acc: 0.68359 | v_loss: 1.67626 v_acc: 0.66211 |  iteration: 120 teacher: 0 stage: inpainting
# batch 120 loss: 1.78770 acc: 0.66667 | v_loss: 1.45035 v_acc: 0.68815 |  iteration: 121 teacher: 1 stage: inpainting
# batch 121 loss: 1.77546 acc: 0.67578 | v_loss: 1.53508 v_acc: 0.67676 |  iteration: 122 teacher: 0 stage: inpainting
# batch 122 loss: 1.72203 acc: 0.67611 | v_loss: 1.49980 v_acc: 0.69727 |  iteration: 123 teacher: 0 stage: inpainting
# batch 123 loss: 1.64616 acc: 0.67708 | v_loss: 1.66991 v_acc: 0.67546 |  iteration: 124 teacher: 1 stage: inpainting
# batch 124 loss: 1.73491 acc: 0.68555 | v_loss: 1.46278 v_acc: 0.69531 |  iteration: 125 teacher: 1 stage: inpainting
# batch 125 loss: 1.58060 acc: 0.68717 | v_loss: 1.75796 v_acc: 0.65723 |  iteration: 126 teacher: 1 stage: inpainting
# batch 126 loss: 1.67656 acc: 0.67936 | v_loss: 1.50614 v_acc: 0.69694 |  iteration: 127 teacher: 0 stage: inpainting
# batch 127 loss: 1.71326 acc: 0.68685 | v_loss: 1.68807 v_acc: 0.67155 |  iteration: 128 teacher: 0 stage: inpainting
# batch 128 loss: 1.58509 acc: 0.69759 | v_loss: 1.66464 v_acc: 0.66992 |  iteration: 129 teacher: 1 stage: inpainting
# batch 129 loss: 1.63953 acc: 0.68750 | v_loss: 1.60522 v_acc: 0.66829 |  iteration: 130 teacher: 0 stage: inpainting
# batch 130 loss: 1.57087 acc: 0.69010 | v_loss: 1.50451 v_acc: 0.68229 |  iteration: 131 teacher: 0 stage: inpainting
# batch 131 loss: 1.73782 acc: 0.66732 | v_loss: 1.51079 v_acc: 0.70378 |  iteration: 132 teacher: 0 stage: inpainting
# batch 132 loss: 1.67094 acc: 0.68620 | v_loss: 1.66114 v_acc: 0.67285 |  iteration: 133 teacher: 1 stage: inpainting
# batch 133 loss: 1.57832 acc: 0.70150 | v_loss: 1.48047 v_acc: 0.68197 |  iteration: 134 teacher: 0 stage: inpainting
# batch 134 loss: 1.71588 acc: 0.67188 | v_loss: 1.76151 v_acc: 0.66243 |  iteration: 135 teacher: 0 stage: inpainting
# batch 135 loss: 1.59015 acc: 0.69303 | v_loss: 1.57134 v_acc: 0.66569 |  iteration: 136 teacher: 0 stage: inpainting
# batch 136 loss: 1.54504 acc: 0.69922 | v_loss: 1.44839 v_acc: 0.70150 |  iteration: 137 teacher: 0 stage: inpainting
# batch 137 loss: 1.67808 acc: 0.68066 | v_loss: 1.41064 v_acc: 0.70410 |  iteration: 138 teacher: 1 stage: inpainting
# batch 138 loss: 1.71939 acc: 0.67513 | v_loss: 1.45248 v_acc: 0.68978 |  iteration: 139 teacher: 0 stage: inpainting
# batch 139 loss: 1.58648 acc: 0.68783 | v_loss: 1.52985 v_acc: 0.67318 |  iteration: 140 teacher: 0 stage: inpainting
# batch 140 loss: 1.71655 acc: 0.68262 | v_loss: 1.47958 v_acc: 0.68587 |  iteration: 141 teacher: 1 stage: inpainting
# batch 141 loss: 1.58079 acc: 0.67643 | v_loss: 1.32843 v_acc: 0.69629 |  iteration: 142 teacher: 0 stage: inpainting
# batch 142 loss: 1.51440 acc: 0.68978 | v_loss: 1.31486 v_acc: 0.71289 |  iteration: 143 teacher: 1 stage: inpainting
# batch 143 loss: 1.57180 acc: 0.68457 | v_loss: 1.46298 v_acc: 0.68229 |  iteration: 144 teacher: 0 stage: inpainting
# batch 144 loss: 1.47391 acc: 0.71029 | v_loss: 1.50802 v_acc: 0.68555 |  iteration: 145 teacher: 1 stage: inpainting
# batch 145 loss: 1.56849 acc: 0.67676 | v_loss: 1.40335 v_acc: 0.69889 |  iteration: 146 teacher: 0 stage: inpainting
# batch 146 loss: 1.72844 acc: 0.67155 | v_loss: 1.37249 v_acc: 0.71159 |  iteration: 147 teacher: 1 stage: inpainting
# batch 147 loss: 1.60670 acc: 0.68457 | v_loss: 1.43575 v_acc: 0.71257 |  iteration: 148 teacher: 1 stage: inpainting
# batch 148 loss: 1.45946 acc: 0.70150 | v_loss: 1.48717 v_acc: 0.69954 |  iteration: 149 teacher: 0 stage: inpainting
# batch 149 loss: 1.59339 acc: 0.69336 | v_loss: 1.34510 v_acc: 0.70768 |  iteration: 150 teacher: 1 stage: inpainting
# batch 150 loss: 1.51812 acc: 0.69206 | v_loss: 1.30776 v_acc: 0.70703 |  iteration: 151 teacher: 0 stage: inpainting
# batch 151 loss: 1.51305 acc: 0.70085 | v_loss: 1.33752 v_acc: 0.71452 |  iteration: 152 teacher: 1 stage: inpainting
# batch 152 loss: 1.58050 acc: 0.68457 | v_loss: 1.32978 v_acc: 0.72005 |  iteration: 153 teacher: 1 stage: inpainting
# batch 153 loss: 1.54490 acc: 0.68783 | v_loss: 1.43819 v_acc: 0.69141 |  iteration: 154 teacher: 1 stage: inpainting
# batch 154 loss: 1.52971 acc: 0.69857 | v_loss: 1.51110 v_acc: 0.66634 |  iteration: 155 teacher: 1 stage: inpainting
# batch 155 loss: 1.58305 acc: 0.66732 | v_loss: 1.44783 v_acc: 0.69824 |  iteration: 156 teacher: 0 stage: inpainting
# batch 156 loss: 1.52685 acc: 0.69368 | v_loss: 1.48524 v_acc: 0.69889 |  iteration: 157 teacher: 1 stage: inpainting
# batch 157 loss: 1.51207 acc: 0.69954 | v_loss: 1.64220 v_acc: 0.68880 |  iteration: 158 teacher: 0 stage: inpainting
# batch 158 loss: 1.52991 acc: 0.69010 | v_loss: 1.53131 v_acc: 0.68424 |  iteration: 159 teacher: 0 stage: inpainting
# batch 159 loss: 1.48288 acc: 0.69596 | v_loss: 1.34985 v_acc: 0.70052 |  iteration: 160 teacher: 1 stage: inpainting
# batch 160 loss: 1.51637 acc: 0.69434 | v_loss: 1.43277 v_acc: 0.69238 |  iteration: 161 teacher: 1 stage: inpainting
# batch 161 loss: 1.56234 acc: 0.68978 | v_loss: 1.22627 v_acc: 0.71810 |  iteration: 162 teacher: 1 stage: inpainting
# batch 162 loss: 1.58476 acc: 0.69173 | v_loss: 1.44893 v_acc: 0.70638 |  iteration: 163 teacher: 0 stage: inpainting
# batch 163 loss: 1.46659 acc: 0.69434 | v_loss: 1.35004 v_acc: 0.70703 |  iteration: 164 teacher: 1 stage: inpainting
# batch 164 loss: 1.46679 acc: 0.69857 | v_loss: 1.41827 v_acc: 0.70898 |  iteration: 165 teacher: 0 stage: inpainting
# batch 165 loss: 1.48042 acc: 0.69629 | v_loss: 1.37045 v_acc: 0.69629 |  iteration: 166 teacher: 1 stage: inpainting
# batch 166 loss: 1.55502 acc: 0.68001 | v_loss: 1.42369 v_acc: 0.68685 |  iteration: 167 teacher: 1 stage: inpainting
# batch 167 loss: 1.56447 acc: 0.68164 | v_loss: 1.40099 v_acc: 0.70052 |  iteration: 168 teacher: 1 stage: inpainting
# batch 168 loss: 1.58968 acc: 0.67383 | v_loss: 1.34791 v_acc: 0.70280 |  iteration: 169 teacher: 1 stage: inpainting
# batch 169 loss: 1.46352 acc: 0.70020 | v_loss: 1.63594 v_acc: 0.66667 |  iteration: 170 teacher: 0 stage: inpainting
# batch 170 loss: 1.57720 acc: 0.68945 | v_loss: 1.37490 v_acc: 0.69727 |  iteration: 171 teacher: 1 stage: inpainting
# batch 171 loss: 1.42128 acc: 0.69987 | v_loss: 1.43971 v_acc: 0.70182 |  iteration: 172 teacher: 1 stage: inpainting
# batch 172 loss: 1.51903 acc: 0.69271 | v_loss: 1.32341 v_acc: 0.70736 |  iteration: 173 teacher: 0 stage: inpainting
# batch 173 loss: 1.36126 acc: 0.71029 | v_loss: 1.51011 v_acc: 0.69010 |  iteration: 174 teacher: 1 stage: inpainting
# batch 174 loss: 1.47220 acc: 0.69857 | v_loss: 1.28366 v_acc: 0.71387 |  iteration: 175 teacher: 1 stage: inpainting
# batch 175 loss: 1.47684 acc: 0.69173 | v_loss: 1.45446 v_acc: 0.70443 |  iteration: 176 teacher: 0 stage: inpainting
# batch 176 loss: 1.52293 acc: 0.69141 | v_loss: 1.34684 v_acc: 0.70117 |  iteration: 177 teacher: 1 stage: inpainting
# batch 177 loss: 1.42922 acc: 0.69499 | v_loss: 1.40418 v_acc: 0.70378 |  iteration: 178 teacher: 1 stage: inpainting
# batch 178 loss: 1.52189 acc: 0.69629 | v_loss: 1.42539 v_acc: 0.69857 |  iteration: 179 teacher: 0 stage: inpainting
# batch 179 loss: 1.44498 acc: 0.70443 | v_loss: 1.53597 v_acc: 0.68587 |  iteration: 180 teacher: 1 stage: inpainting
# batch 180 loss: 1.41749 acc: 0.70085 | v_loss: 1.68413 v_acc: 0.64486 |  iteration: 181 teacher: 1 stage: inpainting
# batch 181 loss: 1.71499 acc: 0.65104 | v_loss: 1.35290 v_acc: 0.69596 |  iteration: 182 teacher: 0 stage: inpainting
# batch 182 loss: 1.44616 acc: 0.69531 | v_loss: 1.42792 v_acc: 0.69694 |  iteration: 183 teacher: 0 stage: inpainting
# batch 183 loss: 1.59876 acc: 0.68717 | v_loss: 1.31185 v_acc: 0.70768 |  iteration: 184 teacher: 0 stage: inpainting
# batch 184 loss: 1.36653 acc: 0.71647 | v_loss: 1.44585 v_acc: 0.69727 |  iteration: 185 teacher: 1 stage: inpainting
# batch 185 loss: 1.44755 acc: 0.69401 | v_loss: 1.32120 v_acc: 0.70768 |  iteration: 186 teacher: 1 stage: inpainting
# batch 186 loss: 1.54679 acc: 0.69564 | v_loss: 1.33286 v_acc: 0.72298 |  iteration: 187 teacher: 0 stage: inpainting
# batch 187 loss: 1.35184 acc: 0.71224 | v_loss: 1.27080 v_acc: 0.71322 |  iteration: 188 teacher: 1 stage: inpainting
# batch 188 loss: 1.40988 acc: 0.68359 | v_loss: 1.50512 v_acc: 0.68164 |  iteration: 189 teacher: 1 stage: inpainting
# batch 189 loss: 1.39512 acc: 0.69010 | v_loss: 1.60974 v_acc: 0.68262 |  iteration: 190 teacher: 1 stage: inpainting
# batch 190 loss: 1.41871 acc: 0.70345 | v_loss: 1.47896 v_acc: 0.69043 |  iteration: 191 teacher: 1 stage: inpainting
# batch 191 loss: 1.58959 acc: 0.66927 | v_loss: 1.47405 v_acc: 0.69661 |  iteration: 192 teacher: 0 stage: inpainting
# batch 192 loss: 1.38416 acc: 0.70508 | v_loss: 1.35969 v_acc: 0.70215 |  iteration: 193 teacher: 1 stage: inpainting
# batch 193 loss: 1.41748 acc: 0.70443 | v_loss: 1.29720 v_acc: 0.70378 |  iteration: 194 teacher: 1 stage: inpainting
# batch 194 loss: 1.35340 acc: 0.70052 | v_loss: 1.20633 v_acc: 0.73307 |  iteration: 195 teacher: 1 stage: inpainting
# batch 195 loss: 1.40416 acc: 0.71354 | v_loss: 1.33230 v_acc: 0.71257 |  iteration: 196 teacher: 1 stage: inpainting
# batch 196 loss: 1.51438 acc: 0.69271 | v_loss: 1.19878 v_acc: 0.73470 |  iteration: 197 teacher: 0 stage: inpainting
# batch 197 loss: 1.34756 acc: 0.70378 | v_loss: 1.22419 v_acc: 0.70996 |  iteration: 198 teacher: 1 stage: inpainting
# batch 198 loss: 1.47339 acc: 0.69759 | v_loss: 1.30287 v_acc: 0.71842 |  iteration: 199 teacher: 0 stage: inpainting
# batch 199 loss: 1.34393 acc: 0.70182 | v_loss: 1.24222 v_acc: 0.71224 |  iteration: 200 teacher: 1 stage: inpainting
# batch 200 loss: 1.34519 acc: 0.69759 | v_loss: 1.22468 v_acc: 0.71159 |  iteration: 201 teacher: 1 stage: inpainting
# batch 201 loss: 1.37634 acc: 0.70215 | v_loss: 1.40303 v_acc: 0.68685 |  iteration: 202 teacher: 1 stage: inpainting
# batch 202 loss: 1.37374 acc: 0.70312 | v_loss: 1.29700 v_acc: 0.70215 |  iteration: 203 teacher: 0 stage: inpainting
# batch 203 loss: 1.35344 acc: 0.69922 | v_loss: 1.24073 v_acc: 0.72266 |  iteration: 204 teacher: 1 stage: inpainting
# batch 204 loss: 1.41272 acc: 0.69629 | v_loss: 1.34090 v_acc: 0.69661 |  iteration: 205 teacher: 0 stage: inpainting
# batch 205 loss: 1.38713 acc: 0.69792 | v_loss: 1.35992 v_acc: 0.70605 |  iteration: 206 teacher: 0 stage: inpainting
# batch 206 loss: 1.41736 acc: 0.69727 | v_loss: 1.46436 v_acc: 0.69987 |  iteration: 207 teacher: 0 stage: inpainting
# batch 207 loss: 1.47181 acc: 0.68783 | v_loss: 1.27563 v_acc: 0.69922 |  iteration: 208 teacher: 0 stage: inpainting
# batch 208 loss: 1.41878 acc: 0.69727 | v_loss: 1.35671 v_acc: 0.69434 |  iteration: 209 teacher: 0 stage: inpainting
# batch 209 loss: 1.35558 acc: 0.70410 | v_loss: 1.30478 v_acc: 0.70312 |  iteration: 210 teacher: 1 stage: inpainting
# batch 210 loss: 1.31039 acc: 0.71387 | v_loss: 1.45337 v_acc: 0.69141 |  iteration: 211 teacher: 1 stage: inpainting
# batch 211 loss: 1.15867 acc: 0.72754 | v_loss: 1.18874 v_acc: 0.72884 |  iteration: 212 teacher: 1 stage: inpainting
# batch 212 loss: 1.41760 acc: 0.70508 | v_loss: 1.22478 v_acc: 0.71419 |  iteration: 213 teacher: 0 stage: inpainting
# batch 213 loss: 1.43366 acc: 0.69206 | v_loss: 1.24882 v_acc: 0.71452 |  iteration: 214 teacher: 0 stage: inpainting
# batch 214 loss: 1.23607 acc: 0.71094 | v_loss: 1.46938 v_acc: 0.66992 |  iteration: 215 teacher: 1 stage: inpainting
# batch 215 loss: 1.48858 acc: 0.67643 | v_loss: 1.31197 v_acc: 0.70573 |  iteration: 216 teacher: 0 stage: inpainting
# batch 216 loss: 1.35144 acc: 0.70703 | v_loss: 1.45996 v_acc: 0.69466 |  iteration: 217 teacher: 0 stage: inpainting
# batch 217 loss: 1.34087 acc: 0.70312 | v_loss: 1.27163 v_acc: 0.72233 |  iteration: 218 teacher: 0 stage: inpainting
# batch 218 loss: 1.25643 acc: 0.70898 | v_loss: 1.65199 v_acc: 0.69010 |  iteration: 219 teacher: 1 stage: inpainting
# batch 219 loss: 1.49704 acc: 0.69759 | v_loss: 1.50165 v_acc: 0.70020 |  iteration: 220 teacher: 0 stage: inpainting
# batch 220 loss: 1.49999 acc: 0.69564 | v_loss: 1.34517 v_acc: 0.69954 |  iteration: 221 teacher: 0 stage: inpainting
# batch 221 loss: 1.27815 acc: 0.70964 | v_loss: 1.40667 v_acc: 0.68034 |  iteration: 222 teacher: 1 stage: inpainting
# batch 222 loss: 1.25834 acc: 0.71549 | v_loss: 1.53748 v_acc: 0.65918 |  iteration: 223 teacher: 1 stage: inpainting
# batch 223 loss: 1.31375 acc: 0.71549 | v_loss: 1.90581 v_acc: 0.57780 |  iteration: 224 teacher: 1 stage: inpainting
# batch 224 loss: 1.79297 acc: 0.61686 | v_loss: 1.37306 v_acc: 0.68327 |  iteration: 225 teacher: 0 stage: inpainting
# batch 225 loss: 1.29079 acc: 0.70638 | v_loss: 1.54364 v_acc: 0.67969 |  iteration: 226 teacher: 1 stage: inpainting
# batch 226 loss: 1.31295 acc: 0.70703 | v_loss: 1.30466 v_acc: 0.70605 |  iteration: 227 teacher: 0 stage: inpainting
# batch 227 loss: 1.38503 acc: 0.70638 | v_loss: 1.28310 v_acc: 0.71680 |  iteration: 228 teacher: 0 stage: inpainting
# batch 228 loss: 1.34447 acc: 0.71289 | v_loss: 1.31441 v_acc: 0.71940 |  iteration: 229 teacher: 0 stage: inpainting
# batch 229 loss: 1.45076 acc: 0.70736 | v_loss: 1.36644 v_acc: 0.70605 |  iteration: 230 teacher: 1 stage: inpainting
# batch 230 loss: 1.23460 acc: 0.71745 | v_loss: 1.34702 v_acc: 0.69206 |  iteration: 231 teacher: 1 stage: inpainting
# batch 231 loss: 1.47065 acc: 0.70345 | v_loss: 1.28157 v_acc: 0.71875 |  iteration: 232 teacher: 0 stage: inpainting
# batch 232 loss: 1.33942 acc: 0.70833 | v_loss: 1.19416 v_acc: 0.71029 |  iteration: 233 teacher: 0 stage: inpainting
# batch 233 loss: 1.21734 acc: 0.72038 | v_loss: 1.23350 v_acc: 0.72884 |  iteration: 234 teacher: 1 stage: inpainting
# batch 234 loss: 1.36379 acc: 0.70052 | v_loss: 1.31702 v_acc: 0.70508 |  iteration: 235 teacher: 1 stage: inpainting
# batch 235 loss: 1.27376 acc: 0.71029 | v_loss: 1.43795 v_acc: 0.69401 |  iteration: 236 teacher: 1 stage: inpainting
# batch 236 loss: 1.20169 acc: 0.72135 | v_loss: 1.42462 v_acc: 0.68750 |  iteration: 237 teacher: 1 stage: inpainting
# batch 237 loss: 1.30729 acc: 0.69303 | v_loss: 1.45736 v_acc: 0.67513 |  iteration: 238 teacher: 1 stage: inpainting
# batch 238 loss: 1.34362 acc: 0.69043 | v_loss: 1.54324 v_acc: 0.66732 |  iteration: 239 teacher: 1 stage: inpainting
# batch 239 loss: 1.49353 acc: 0.66634 | v_loss: 1.46791 v_acc: 0.69173 |  iteration: 240 teacher: 0 stage: inpainting
# batch 240 loss: 1.16881 acc: 0.72689 | v_loss: 1.30427 v_acc: 0.70052 |  iteration: 241 teacher: 1 stage: inpainting
# batch 241 loss: 1.32039 acc: 0.70540 | v_loss: 1.28757 v_acc: 0.70671 |  iteration: 242 teacher: 1 stage: inpainting
# batch 242 loss: 1.18439 acc: 0.72396 | v_loss: 1.27793 v_acc: 0.71875 |  iteration: 243 teacher: 1 stage: inpainting
# batch 243 loss: 1.48131 acc: 0.68457 | v_loss: 1.23750 v_acc: 0.71159 |  iteration: 244 teacher: 0 stage: inpainting
# batch 244 loss: 1.21492 acc: 0.72754 | v_loss: 1.28194 v_acc: 0.70020 |  iteration: 245 teacher: 1 stage: inpainting
# batch 245 loss: 1.37084 acc: 0.70085 | v_loss: 1.19393 v_acc: 0.70150 |  iteration: 246 teacher: 0 stage: inpainting
# batch 246 loss: 1.11962 acc: 0.72754 | v_loss: 1.27544 v_acc: 0.70866 |  iteration: 247 teacher: 1 stage: inpainting
# batch 247 loss: 1.22508 acc: 0.72559 | v_loss: 1.37330 v_acc: 0.71712 |  iteration: 248 teacher: 1 stage: inpainting
# batch 248 loss: 1.31941 acc: 0.71126 | v_loss: 1.52151 v_acc: 0.69401 |  iteration: 249 teacher: 0 stage: inpainting
# batch 249 loss: 1.24497 acc: 0.70671 | v_loss: 1.35015 v_acc: 0.69694 |  iteration: 250 teacher: 1 stage: inpainting
# batch 250 loss: 1.16791 acc: 0.71647 | v_loss: 1.19751 v_acc: 0.71582 |  iteration: 251 teacher: 1 stage: inpainting
# batch 251 loss: 1.25607 acc: 0.70964 | v_loss: 1.28315 v_acc: 0.69954 |  iteration: 252 teacher: 1 stage: inpainting
# batch 252 loss: 1.31043 acc: 0.71647 | v_loss: 1.08836 v_acc: 0.72363 |  iteration: 253 teacher: 0 stage: inpainting
# batch 253 loss: 1.29268 acc: 0.69792 | v_loss: 1.30175 v_acc: 0.70638 |  iteration: 254 teacher: 1 stage: inpainting
# batch 254 loss: 1.17324 acc: 0.70996 | v_loss: 1.20369 v_acc: 0.71289 |  iteration: 255 teacher: 1 stage: inpainting
# batch 255 loss: 1.27781 acc: 0.70508 | v_loss: 1.27267 v_acc: 0.72201 |  iteration: 256 teacher: 1 stage: inpainting
# batch 256 loss: 1.30504 acc: 0.71810 | v_loss: 1.18128 v_acc: 0.72298 |  iteration: 257 teacher: 0 stage: inpainting
# batch 257 loss: 1.31192 acc: 0.70671 | v_loss: 1.17958 v_acc: 0.70898 |  iteration: 258 teacher: 0 stage: inpainting
# batch 258 loss: 1.14434 acc: 0.72201 | v_loss: 1.24774 v_acc: 0.70150 |  iteration: 259 teacher: 1 stage: inpainting
# batch 259 loss: 1.46268 acc: 0.69336 | v_loss: 1.11963 v_acc: 0.71810 |  iteration: 260 teacher: 0 stage: inpainting
# batch 260 loss: 1.26344 acc: 0.70801 | v_loss: 1.33688 v_acc: 0.69206 |  iteration: 261 teacher: 0 stage: inpainting
# batch 261 loss: 1.13895 acc: 0.71777 | v_loss: 1.23340 v_acc: 0.70508 |  iteration: 262 teacher: 1 stage: inpainting
# batch 262 loss: 1.29685 acc: 0.69694 | v_loss: 1.28001 v_acc: 0.70931 |  iteration: 263 teacher: 0 stage: inpainting
# batch 263 loss: 1.20867 acc: 0.71647 | v_loss: 1.23858 v_acc: 0.70182 |  iteration: 264 teacher: 1 stage: inpainting
# batch 264 loss: 1.15992 acc: 0.72428 | v_loss: 1.33680 v_acc: 0.70052 |  iteration: 265 teacher: 1 stage: inpainting
# batch 265 loss: 1.45565 acc: 0.68197 | v_loss: 1.07564 v_acc: 0.73991 |  iteration: 266 teacher: 0 stage: inpainting
# batch 266 loss: 1.26767 acc: 0.70573 | v_loss: 1.28919 v_acc: 0.70182 |  iteration: 267 teacher: 0 stage: inpainting
# batch 267 loss: 1.19826 acc: 0.71517 | v_loss: 1.20168 v_acc: 0.70703 |  iteration: 268 teacher: 1 stage: inpainting
# batch 268 loss: 1.30094 acc: 0.70898 | v_loss: 1.28584 v_acc: 0.70605 |  iteration: 269 teacher: 0 stage: inpainting
# batch 269 loss: 1.28379 acc: 0.70898 | v_loss: 1.18395 v_acc: 0.71289 |  iteration: 270 teacher: 0 stage: inpainting
# batch 270 loss: 1.25101 acc: 0.70410 | v_loss: 1.31428 v_acc: 0.70964 |  iteration: 271 teacher: 0 stage: inpainting
# batch 271 loss: 1.19860 acc: 0.71191 | v_loss: 1.44545 v_acc: 0.68392 |  iteration: 272 teacher: 1 stage: inpainting
# batch 272 loss: 1.27771 acc: 0.70671 | v_loss: 1.24798 v_acc: 0.69564 |  iteration: 273 teacher: 0 stage: inpainting
# batch 273 loss: 1.20953 acc: 0.71419 | v_loss: 1.22000 v_acc: 0.71582 |  iteration: 274 teacher: 1 stage: inpainting
# batch 274 loss: 1.13089 acc: 0.71647 | v_loss: 1.12673 v_acc: 0.71257 |  iteration: 275 teacher: 1 stage: inpainting
# batch 275 loss: 1.22294 acc: 0.70866 | v_loss: 1.15043 v_acc: 0.70638 |  iteration: 276 teacher: 1 stage: inpainting
# batch 276 loss: 1.19885 acc: 0.71289 | v_loss: 1.11243 v_acc: 0.71191 |  iteration: 277 teacher: 1 stage: inpainting
# batch 277 loss: 1.30902 acc: 0.70085 | v_loss: 1.18058 v_acc: 0.72526 |  iteration: 278 teacher: 0 stage: inpainting
# batch 278 loss: 1.12696 acc: 0.72591 | v_loss: 1.05208 v_acc: 0.71452 |  iteration: 279 teacher: 1 stage: inpainting
# batch 279 loss: 1.20918 acc: 0.71191 | v_loss: 1.21668 v_acc: 0.70508 |  iteration: 280 teacher: 1 stage: inpainting
# batch 280 loss: 1.31628 acc: 0.69238 | v_loss: 1.36831 v_acc: 0.69108 |  iteration: 281 teacher: 0 stage: inpainting
# batch 281 loss: 1.21411 acc: 0.70410 | v_loss: 1.13128 v_acc: 0.71094 |  iteration: 282 teacher: 1 stage: inpainting
# batch 282 loss: 1.19230 acc: 0.72070 | v_loss: 1.18318 v_acc: 0.70410 |  iteration: 283 teacher: 0 stage: inpainting
# batch 283 loss: 1.32946 acc: 0.69629 | v_loss: 1.16161 v_acc: 0.70475 |  iteration: 284 teacher: 0 stage: inpainting
# batch 284 loss: 1.44348 acc: 0.68262 | v_loss: 1.12558 v_acc: 0.69759 |  iteration: 285 teacher: 0 stage: inpainting
# batch 285 loss: 1.26586 acc: 0.69434 | v_loss: 1.05633 v_acc: 0.72852 |  iteration: 286 teacher: 1 stage: inpainting
# batch 286 loss: 1.13287 acc: 0.71322 | v_loss: 1.16963 v_acc: 0.69824 |  iteration: 287 teacher: 1 stage: inpainting
# batch 287 loss: 1.30223 acc: 0.70443 | v_loss: 1.10708 v_acc: 0.71973 |  iteration: 288 teacher: 0 stage: inpainting
# batch 288 loss: 1.30204 acc: 0.69629 | v_loss: 1.02798 v_acc: 0.71517 |  iteration: 289 teacher: 0 stage: inpainting
# batch 289 loss: 1.15305 acc: 0.72135 | v_loss: 1.13567 v_acc: 0.72266 |  iteration: 290 teacher: 1 stage: inpainting
# batch 290 loss: 1.16719 acc: 0.71257 | v_loss: 1.23043 v_acc: 0.70378 |  iteration: 291 teacher: 1 stage: inpainting
# batch 291 loss: 1.28666 acc: 0.69401 | v_loss: 1.13652 v_acc: 0.71126 |  iteration: 292 teacher: 0 stage: inpainting
# batch 292 loss: 1.30946 acc: 0.68132 | v_loss: 1.23813 v_acc: 0.70312 |  iteration: 293 teacher: 0 stage: inpainting
# batch 293 loss: 1.18427 acc: 0.71582 | v_loss: 1.14583 v_acc: 0.71354 |  iteration: 294 teacher: 1 stage: inpainting
# batch 294 loss: 1.07783 acc: 0.71647 | v_loss: 1.10473 v_acc: 0.72917 |  iteration: 295 teacher: 1 stage: inpainting
# batch 295 loss: 1.43261 acc: 0.68880 | v_loss: 1.18609 v_acc: 0.70801 |  iteration: 296 teacher: 0 stage: inpainting
# batch 296 loss: 1.15883 acc: 0.71647 | v_loss: 1.18178 v_acc: 0.71061 |  iteration: 297 teacher: 0 stage: inpainting
# batch 297 loss: 1.38506 acc: 0.69010 | v_loss: 1.27767 v_acc: 0.71745 |  iteration: 298 teacher: 0 stage: inpainting
# batch 298 loss: 1.09821 acc: 0.72005 | v_loss: 1.21800 v_acc: 0.70833 |  iteration: 299 teacher: 1 stage: inpainting
# batch 299 loss: 1.37034 acc: 0.69792 | v_loss: 1.21567 v_acc: 0.69694 |  iteration: 300 teacher: 0 stage: inpainting
# batch 300 loss: 1.15612 acc: 0.71126 | v_loss: 1.12417 v_acc: 0.71257 |  iteration: 301 teacher: 0 stage: inpainting
# batch 301 loss: 1.02122 acc: 0.73275 | v_loss: 1.18707 v_acc: 0.70345 |  iteration: 302 teacher: 1 stage: inpainting
# batch 302 loss: 1.30098 acc: 0.70443 | v_loss: 1.00284 v_acc: 0.72461 |  iteration: 303 teacher: 0 stage: inpainting
# batch 303 loss: 1.16118 acc: 0.72005 | v_loss: 1.05183 v_acc: 0.72005 |  iteration: 304 teacher: 1 stage: inpainting
# batch 304 loss: 1.14219 acc: 0.71354 | v_loss: 1.09161 v_acc: 0.71680 |  iteration: 305 teacher: 1 stage: inpainting
# batch 305 loss: 1.13694 acc: 0.71452 | v_loss: 1.32133 v_acc: 0.69922 |  iteration: 306 teacher: 1 stage: inpainting
# batch 306 loss: 1.20113 acc: 0.70605 | v_loss: 1.07567 v_acc: 0.71061 |  iteration: 307 teacher: 0 stage: inpainting
# batch 307 loss: 1.26796 acc: 0.70410 | v_loss: 1.26965 v_acc: 0.69303 |  iteration: 308 teacher: 0 stage: inpainting
# batch 308 loss: 1.11845 acc: 0.71484 | v_loss: 1.14754 v_acc: 0.72754 |  iteration: 309 teacher: 1 stage: inpainting
# batch 309 loss: 1.14705 acc: 0.71484 | v_loss: 1.37682 v_acc: 0.68717 |  iteration: 310 teacher: 1 stage: inpainting
# batch 310 loss: 1.23675 acc: 0.69987 | v_loss: 1.24059 v_acc: 0.70085 |  iteration: 311 teacher: 0 stage: inpainting
# batch 311 loss: 1.08256 acc: 0.71973 | v_loss: 1.16655 v_acc: 0.70345 |  iteration: 312 teacher: 1 stage: inpainting
# batch 312 loss: 1.24380 acc: 0.70280 | v_loss: 1.10321 v_acc: 0.70150 |  iteration: 313 teacher: 0 stage: inpainting
# batch 313 loss: 1.16487 acc: 0.70638 | v_loss: 1.08873 v_acc: 0.71354 |  iteration: 314 teacher: 0 stage: inpainting
# batch 314 loss: 1.07517 acc: 0.72005 | v_loss: 1.16749 v_acc: 0.70768 |  iteration: 315 teacher: 1 stage: inpainting
# batch 315 loss: 1.19657 acc: 0.71126 | v_loss: 1.04583 v_acc: 0.72135 |  iteration: 316 teacher: 0 stage: inpainting
# batch 316 loss: 1.18226 acc: 0.71387 | v_loss: 1.28764 v_acc: 0.68945 |  iteration: 317 teacher: 0 stage: inpainting
# batch 317 loss: 1.06981 acc: 0.72135 | v_loss: 1.15453 v_acc: 0.70052 |  iteration: 318 teacher: 1 stage: inpainting
# batch 318 loss: 1.07266 acc: 0.71973 | v_loss: 1.01781 v_acc: 0.72624 |  iteration: 319 teacher: 1 stage: inpainting
# batch 319 loss: 1.06034 acc: 0.71517 | v_loss: 1.13483 v_acc: 0.71973 |  iteration: 320 teacher: 1 stage: inpainting
# batch 320 loss: 1.12015 acc: 0.72591 | v_loss: 1.17135 v_acc: 0.71940 |  iteration: 321 teacher: 1 stage: inpainting
# batch 321 loss: 1.08242 acc: 0.71908 | v_loss: 1.17940 v_acc: 0.70312 |  iteration: 322 teacher: 1 stage: inpainting
# batch 322 loss: 1.03353 acc: 0.72884 | v_loss: 1.13848 v_acc: 0.72135 |  iteration: 323 teacher: 1 stage: inpainting
# batch 323 loss: 1.09453 acc: 0.72754 | v_loss: 1.00458 v_acc: 0.72005 |  iteration: 324 teacher: 0 stage: inpainting
# batch 324 loss: 1.13699 acc: 0.70866 | v_loss: 0.96744 v_acc: 0.73828 |  iteration: 325 teacher: 0 stage: inpainting
# batch 325 loss: 1.07329 acc: 0.72135 | v_loss: 1.05434 v_acc: 0.72396 |  iteration: 326 teacher: 1 stage: inpainting
# batch 326 loss: 1.05248 acc: 0.72982 | v_loss: 1.18333 v_acc: 0.70866 |  iteration: 327 teacher: 1 stage: inpainting
# batch 327 loss: 1.08164 acc: 0.72201 | v_loss: 1.17634 v_acc: 0.70768 |  iteration: 328 teacher: 1 stage: inpainting
# batch 328 loss: 1.19662 acc: 0.70247 | v_loss: 1.12291 v_acc: 0.70540 |  iteration: 329 teacher: 1 stage: inpainting
# batch 329 loss: 1.15544 acc: 0.70866 | v_loss: 1.24523 v_acc: 0.69434 |  iteration: 330 teacher: 1 stage: inpainting
# batch 330 loss: 1.21139 acc: 0.70898 | v_loss: 1.23518 v_acc: 0.69271 |  iteration: 331 teacher: 0 stage: inpainting
# batch 331 loss: 1.21284 acc: 0.70378 | v_loss: 1.09084 v_acc: 0.72428 |  iteration: 332 teacher: 0 stage: inpainting
# batch 332 loss: 1.19114 acc: 0.71159 | v_loss: 1.12022 v_acc: 0.71224 |  iteration: 333 teacher: 0 stage: inpainting
# batch 333 loss: 1.21611 acc: 0.70052 | v_loss: 1.18869 v_acc: 0.72493 |  iteration: 334 teacher: 0 stage: inpainting
# batch 334 loss: 1.31332 acc: 0.68815 | v_loss: 1.18685 v_acc: 0.71647 |  iteration: 335 teacher: 1 stage: inpainting
# batch 335 loss: 1.34279 acc: 0.68132 | v_loss: 1.13333 v_acc: 0.71094 |  iteration: 336 teacher: 0 stage: inpainting
# batch 336 loss: 1.17515 acc: 0.70475 | v_loss: 1.02784 v_acc: 0.71582 |  iteration: 337 teacher: 0 stage: inpainting
# batch 337 loss: 1.13039 acc: 0.71615 | v_loss: 1.09388 v_acc: 0.71224 |  iteration: 338 teacher: 0 stage: inpainting
# batch 338 loss: 1.12049 acc: 0.71875 | v_loss: 1.14793 v_acc: 0.73926 |  iteration: 339 teacher: 1 stage: inpainting
# batch 339 loss: 1.12462 acc: 0.72819 | v_loss: 1.40776 v_acc: 0.69303 |  iteration: 340 teacher: 1 stage: inpainting
# batch 340 loss: 1.41734 acc: 0.69564 | v_loss: 1.20536 v_acc: 0.70150 |  iteration: 341 teacher: 0 stage: inpainting
# batch 341 loss: 1.05355 acc: 0.72559 | v_loss: 1.07054 v_acc: 0.72624 |  iteration: 342 teacher: 1 stage: inpainting
# batch 342 loss: 1.20236 acc: 0.71549 | v_loss: 1.13579 v_acc: 0.70508 |  iteration: 343 teacher: 0 stage: inpainting
# batch 343 loss: 1.05152 acc: 0.72070 | v_loss: 0.98337 v_acc: 0.73079 |  iteration: 344 teacher: 1 stage: inpainting
# batch 344 loss: 1.18573 acc: 0.70605 | v_loss: 1.18740 v_acc: 0.71126 |  iteration: 345 teacher: 1 stage: inpainting
# batch 345 loss: 1.04203 acc: 0.72331 | v_loss: 1.17325 v_acc: 0.72266 |  iteration: 346 teacher: 1 stage: inpainting
# batch 346 loss: 1.07154 acc: 0.72038 | v_loss: 1.19391 v_acc: 0.72852 |  iteration: 347 teacher: 1 stage: inpainting
# batch 347 loss: 1.24639 acc: 0.71094 | v_loss: 1.12432 v_acc: 0.73047 |  iteration: 348 teacher: 0 stage: inpainting
# batch 348 loss: 1.10181 acc: 0.71973 | v_loss: 1.11612 v_acc: 0.71777 |  iteration: 349 teacher: 1 stage: inpainting
# batch 349 loss: 1.06705 acc: 0.72038 | v_loss: 1.06471 v_acc: 0.72070 |  iteration: 350 teacher: 1 stage: inpainting
# batch 350 loss: 1.09345 acc: 0.71647 | v_loss: 0.99968 v_acc: 0.73503 |  iteration: 351 teacher: 1 stage: inpainting
# batch 351 loss: 1.03993 acc: 0.71940 | v_loss: 1.19721 v_acc: 0.69303 |  iteration: 352 teacher: 1 stage: inpainting
# batch 352 loss: 1.26270 acc: 0.69173 | v_loss: 1.05264 v_acc: 0.72396 |  iteration: 353 teacher: 0 stage: inpainting
# batch 353 loss: 1.13522 acc: 0.71745 | v_loss: 1.13351 v_acc: 0.71875 |  iteration: 354 teacher: 1 stage: inpainting
# batch 354 loss: 1.09104 acc: 0.71322 | v_loss: 1.01165 v_acc: 0.72656 |  iteration: 355 teacher: 1 stage: inpainting
# batch 355 loss: 1.15400 acc: 0.71289 | v_loss: 1.13409 v_acc: 0.71224 |  iteration: 356 teacher: 0 stage: inpainting
# batch 356 loss: 1.11869 acc: 0.71419 | v_loss: 0.97691 v_acc: 0.74772 |  iteration: 357 teacher: 1 stage: inpainting
# batch 357 loss: 1.08980 acc: 0.72201 | v_loss: 1.14836 v_acc: 0.72233 |  iteration: 358 teacher: 0 stage: inpainting
# batch 358 loss: 1.01559 acc: 0.72852 | v_loss: 1.07713 v_acc: 0.71029 |  iteration: 359 teacher: 1 stage: inpainting
# batch 359 loss: 1.12138 acc: 0.71484 | v_loss: 1.16611 v_acc: 0.71094 |  iteration: 360 teacher: 0 stage: inpainting
# batch 360 loss: 1.30521 acc: 0.69564 | v_loss: 1.06099 v_acc: 0.72266 |  iteration: 361 teacher: 0 stage: inpainting
# batch 361 loss: 1.09136 acc: 0.71419 | v_loss: 1.15810 v_acc: 0.71712 |  iteration: 362 teacher: 1 stage: inpainting
# batch 362 loss: 1.08551 acc: 0.71029 | v_loss: 1.11915 v_acc: 0.70182 |  iteration: 363 teacher: 0 stage: inpainting
# batch 363 loss: 1.20522 acc: 0.70898 | v_loss: 1.06786 v_acc: 0.72070 |  iteration: 364 teacher: 0 stage: inpainting
# batch 364 loss: 1.07835 acc: 0.72005 | v_loss: 1.06407 v_acc: 0.71908 |  iteration: 365 teacher: 0 stage: inpainting
# batch 365 loss: 1.13848 acc: 0.70833 | v_loss: 1.00787 v_acc: 0.72201 |  iteration: 366 teacher: 0 stage: inpainting
# batch 366 loss: 1.11113 acc: 0.72656 | v_loss: 1.02829 v_acc: 0.72201 |  iteration: 367 teacher: 0 stage: inpainting
# batch 367 loss: 1.09285 acc: 0.71973 | v_loss: 1.03820 v_acc: 0.72201 |  iteration: 368 teacher: 0 stage: inpainting
# batch 368 loss: 1.02172 acc: 0.72038 | v_loss: 1.03313 v_acc: 0.72884 |  iteration: 369 teacher: 1 stage: inpainting
# batch 369 loss: 1.23936 acc: 0.69727 | v_loss: 0.98537 v_acc: 0.72852 |  iteration: 370 teacher: 0 stage: inpainting
# batch 370 loss: 1.00804 acc: 0.72624 | v_loss: 1.09903 v_acc: 0.72038 |  iteration: 371 teacher: 1 stage: inpainting
# batch 371 loss: 1.02338 acc: 0.72428 | v_loss: 1.24049 v_acc: 0.69531 |  iteration: 372 teacher: 0 stage: inpainting
# batch 372 loss: 1.10071 acc: 0.70996 | v_loss: 1.01936 v_acc: 0.71159 |  iteration: 373 teacher: 1 stage: inpainting
# batch 373 loss: 1.10742 acc: 0.71842 | v_loss: 1.05424 v_acc: 0.71549 |  iteration: 374 teacher: 0 stage: inpainting
# batch 374 loss: 1.15949 acc: 0.70996 | v_loss: 0.99974 v_acc: 0.72461 |  iteration: 375 teacher: 0 stage: inpainting
# batch 375 loss: 1.01315 acc: 0.72396 | v_loss: 0.97267 v_acc: 0.72559 |  iteration: 376 teacher: 1 stage: inpainting
# batch 376 loss: 1.20367 acc: 0.71126 | v_loss: 0.91524 v_acc: 0.74544 |  iteration: 377 teacher: 0 stage: inpainting
# batch 377 loss: 1.00793 acc: 0.72721 | v_loss: 1.02098 v_acc: 0.72135 |  iteration: 378 teacher: 1 stage: inpainting
# batch 378 loss: 1.05213 acc: 0.72493 | v_loss: 1.00751 v_acc: 0.72591 |  iteration: 379 teacher: 0 stage: inpainting
# batch 379 loss: 0.93465 acc: 0.73763 | v_loss: 0.95837 v_acc: 0.72526 |  iteration: 380 teacher: 1 stage: inpainting
# batch 380 loss: 1.07401 acc: 0.71322 | v_loss: 1.05085 v_acc: 0.72689 |  iteration: 381 teacher: 1 stage: inpainting
# batch 381 loss: 1.02128 acc: 0.71973 | v_loss: 1.02584 v_acc: 0.72917 |  iteration: 382 teacher: 0 stage: inpainting
# batch 382 loss: 1.04344 acc: 0.72461 | v_loss: 1.00313 v_acc: 0.73210 |  iteration: 383 teacher: 1 stage: inpainting
# batch 383 loss: 1.13744 acc: 0.71647 | v_loss: 1.13895 v_acc: 0.70833 |  iteration: 384 teacher: 0 stage: inpainting
# batch 384 loss: 1.12847 acc: 0.71061 | v_loss: 1.02953 v_acc: 0.72493 |  iteration: 385 teacher: 0 stage: inpainting
# batch 385 loss: 1.07913 acc: 0.71582 | v_loss: 0.96795 v_acc: 0.74414 |  iteration: 386 teacher: 0 stage: inpainting
# batch 386 loss: 1.00852 acc: 0.73047 | v_loss: 1.07123 v_acc: 0.70996 |  iteration: 387 teacher: 1 stage: inpainting
# batch 387 loss: 0.96982 acc: 0.73307 | v_loss: 1.03060 v_acc: 0.72168 |  iteration: 388 teacher: 1 stage: inpainting
# batch 388 loss: 1.20548 acc: 0.70345 | v_loss: 1.15746 v_acc: 0.71875 |  iteration: 389 teacher: 0 stage: inpainting
# batch 389 loss: 1.08203 acc: 0.72070 | v_loss: 1.00629 v_acc: 0.72689 |  iteration: 390 teacher: 0 stage: inpainting
# batch 390 loss: 1.11163 acc: 0.70996 | v_loss: 1.10320 v_acc: 0.71387 |  iteration: 391 teacher: 0 stage: inpainting
# batch 391 loss: 1.11506 acc: 0.72005 | v_loss: 1.08505 v_acc: 0.72135 |  iteration: 392 teacher: 1 stage: inpainting
# batch 392 loss: 1.00379 acc: 0.72591 | v_loss: 1.20788 v_acc: 0.71126 |  iteration: 393 teacher: 1 stage: inpainting
# batch 393 loss: 1.11136 acc: 0.72266 | v_loss: 1.00123 v_acc: 0.73730 |  iteration: 394 teacher: 0 stage: inpainting
# batch 394 loss: 1.14479 acc: 0.71452 | v_loss: 0.98741 v_acc: 0.73535 |  iteration: 395 teacher: 0 stage: inpainting
# batch 395 loss: 1.11662 acc: 0.71875 | v_loss: 0.98041 v_acc: 0.72396 |  iteration: 396 teacher: 0 stage: inpainting
# batch 396 loss: 1.05772 acc: 0.72038 | v_loss: 1.17988 v_acc: 0.70475 |  iteration: 397 teacher: 1 stage: inpainting
# batch 397 loss: 1.04048 acc: 0.72266 | v_loss: 0.99825 v_acc: 0.70996 |  iteration: 398 teacher: 1 stage: inpainting
# batch 398 loss: 1.09778 acc: 0.71061 | v_loss: 1.18319 v_acc: 0.70182 |  iteration: 399 teacher: 1 stage: inpainting
# batch 399 loss: 1.16287 acc: 0.69531 | v_loss: 1.05903 v_acc: 0.71777 |  iteration: 400 teacher: 0 stage: inpainting
# batch 400 loss: 1.05785 acc: 0.71549 | v_loss: 1.18407 v_acc: 0.70280 |  iteration: 401 teacher: 1 stage: inpainting
# batch 401 loss: 0.98454 acc: 0.72949 | v_loss: 1.09596 v_acc: 0.70638 |  iteration: 402 teacher: 1 stage: inpainting
# batch 402 loss: 1.04617 acc: 0.72689 | v_loss: 1.10386 v_acc: 0.69987 |  iteration: 403 teacher: 1 stage: inpainting
# batch 403 loss: 1.05596 acc: 0.71712 | v_loss: 1.04116 v_acc: 0.71159 |  iteration: 404 teacher: 1 stage: inpainting
# batch 404 loss: 1.16770 acc: 0.69987 | v_loss: 1.02753 v_acc: 0.71777 |  iteration: 405 teacher: 0 stage: inpainting
# batch 405 loss: 0.99645 acc: 0.72624 | v_loss: 1.08720 v_acc: 0.70866 |  iteration: 406 teacher: 1 stage: inpainting
# batch 406 loss: 1.05997 acc: 0.71549 | v_loss: 0.97570 v_acc: 0.72852 |  iteration: 407 teacher: 1 stage: inpainting
# batch 407 loss: 1.02483 acc: 0.72982 | v_loss: 1.19113 v_acc: 0.68913 |  iteration: 408 teacher: 0 stage: inpainting
# batch 408 loss: 1.00194 acc: 0.71875 | v_loss: 1.07486 v_acc: 0.70866 |  iteration: 409 teacher: 1 stage: inpainting
# batch 409 loss: 1.11612 acc: 0.70996 | v_loss: 0.92032 v_acc: 0.73438 |  iteration: 410 teacher: 0 stage: inpainting
# batch 410 loss: 1.05031 acc: 0.72266 | v_loss: 1.06424 v_acc: 0.72754 |  iteration: 411 teacher: 0 stage: inpainting
# ...
# batch 640 loss: 0.30404 acc: 0.90625 | v_loss: 0.77511 v_acc: 0.76009 |  iteration: 6856 teacher: 1 stage: inpainting
# batch 641 loss: 0.31768 acc: 0.91178 | v_loss: 0.73692 v_acc: 0.77734 |  iteration: 6857 teacher: 1 stage: inpainting
# batch 642 loss: 0.29360 acc: 0.91504 | v_loss: 0.71317 v_acc: 0.76400 |  iteration: 6858 teacher: 1 stage: inpainting
# batch 643 loss: 0.28533 acc: 0.91439 | v_loss: 0.86749 v_acc: 0.74837 |  iteration: 6859 teacher: 1 stage: inpainting
# batch 644 loss: 0.91833 acc: 0.73177 | v_loss: 0.94765 v_acc: 0.72363 |  iteration: 6860 teacher: 0 stage: inpainting
# batch 645 loss: 0.29406 acc: 0.91276 | v_loss: 0.79328 v_acc: 0.75000 |  iteration: 6861 teacher: 1 stage: inpainting
# batch 646 loss: 0.87522 acc: 0.73763 | v_loss: 0.84833 v_acc: 0.75618 |  iteration: 6862 teacher: 0 stage: inpainting
# batch 647 loss: 0.27496 acc: 0.91862 | v_loss: 0.75562 v_acc: 0.76367 |  iteration: 6863 teacher: 1 stage: inpainting
# batch 648 loss: 0.87846 acc: 0.74479 | v_loss: 0.78910 v_acc: 0.74479 |  iteration: 6864 teacher: 0 stage: inpainting
# batch 649 loss: 0.26295 acc: 0.91732 | v_loss: 0.69816 v_acc: 0.78841 |  iteration: 6865 teacher: 1 stage: inpainting
# batch 650 loss: 0.82779 acc: 0.75130 | v_loss: 0.72789 v_acc: 0.76790 |  iteration: 6866 teacher: 0 stage: inpainting
# batch 651 loss: 0.82549 acc: 0.75358 | v_loss: 0.89148 v_acc: 0.75716 |  iteration: 6867 teacher: 0 stage: inpainting
# batch 652 loss: 0.31023 acc: 0.90625 | v_loss: 0.71715 v_acc: 0.76465 |  iteration: 6868 teacher: 1 stage: inpainting
# batch 653 loss: 0.83691 acc: 0.74740 | v_loss: 0.81175 v_acc: 0.75586 |  iteration: 6869 teacher: 0 stage: inpainting
# batch 654 loss: 0.91734 acc: 0.73698 | v_loss: 0.76671 v_acc: 0.75651 |  iteration: 6870 teacher: 0 stage: inpainting
# batch 655 loss: 0.29425 acc: 0.91829 | v_loss: 0.73700 v_acc: 0.77246 |  iteration: 6871 teacher: 1 stage: inpainting
# batch 656 loss: 0.30136 acc: 0.91569 | v_loss: 0.88946 v_acc: 0.75358 |  iteration: 6872 teacher: 1 stage: inpainting
# batch 657 loss: 0.25645 acc: 0.91862 | v_loss: 0.80680 v_acc: 0.75684 |  iteration: 6873 teacher: 1 stage: inpainting
# batch 658 loss: 0.30590 acc: 0.91406 | v_loss: 0.75000 v_acc: 0.78646 |  iteration: 6874 teacher: 1 stage: inpainting
# batch 659 loss: 0.84468 acc: 0.75228 | v_loss: 0.83303 v_acc: 0.74284 |  iteration: 6875 teacher: 0 stage: inpainting
# batch 660 loss: 0.91765 acc: 0.73177 | v_loss: 0.76248 v_acc: 0.76270 |  iteration: 6876 teacher: 0 stage: inpainting
# batch 661 loss: 0.41805 acc: 0.89323 | v_loss: 0.92398 v_acc: 0.74837 |  iteration: 6877 teacher: 1 stage: inpainting
# batch 662 loss: 0.86093 acc: 0.74219 | v_loss: 0.75225 v_acc: 0.76497 |  iteration: 6878 teacher: 0 stage: inpainting
# batch 663 loss: 0.29145 acc: 0.91569 | v_loss: 0.81823 v_acc: 0.73991 |  iteration: 6879 teacher: 1 stage: inpainting
# batch 664 loss: 0.27161 acc: 0.91667 | v_loss: 0.77454 v_acc: 0.75618 |  iteration: 6880 teacher: 1 stage: inpainting
# batch 665 loss: 0.29973 acc: 0.91276 | v_loss: 0.85753 v_acc: 0.73014 |  iteration: 6881 teacher: 1 stage: inpainting
# batch 666 loss: 0.95429 acc: 0.71517 | v_loss: 0.72146 v_acc: 0.76986 |  iteration: 6882 teacher: 0 stage: inpainting
# batch 667 loss: 0.27540 acc: 0.91536 | v_loss: 0.78044 v_acc: 0.76628 |  iteration: 6883 teacher: 1 stage: inpainting
# batch 668 loss: 0.28443 acc: 0.91536 | v_loss: 0.76115 v_acc: 0.75033 |  iteration: 6884 teacher: 1 stage: inpainting
# batch 669 loss: 0.32787 acc: 0.90560 | v_loss: 1.00596 v_acc: 0.71419 |  iteration: 6885 teacher: 1 stage: inpainting
# batch 670 loss: 0.81958 acc: 0.74349 | v_loss: 0.75373 v_acc: 0.75423 |  iteration: 6886 teacher: 0 stage: inpainting
# batch 671 loss: 0.84333 acc: 0.74251 | v_loss: 0.82976 v_acc: 0.74837 |  iteration: 6887 teacher: 0 stage: inpainting
# batch 672 loss: 0.78869 acc: 0.75814 | v_loss: 0.77252 v_acc: 0.77279 |  iteration: 6888 teacher: 0 stage: inpainting
# batch 673 loss: 0.89476 acc: 0.73242 | v_loss: 0.84409 v_acc: 0.74316 |  iteration: 6889 teacher: 0 stage: inpainting
# batch 674 loss: 0.28896 acc: 0.90820 | v_loss: 0.82146 v_acc: 0.74284 |  iteration: 6890 teacher: 1 stage: inpainting
# batch 675 loss: 0.80248 acc: 0.75358 | v_loss: 0.87394 v_acc: 0.74154 |  iteration: 6891 teacher: 0 stage: inpainting
# batch 676 loss: 0.28287 acc: 0.91146 | v_loss: 0.87748 v_acc: 0.73470 |  iteration: 6892 teacher: 1 stage: inpainting
# batch 677 loss: 0.84721 acc: 0.74577 | v_loss: 0.76250 v_acc: 0.76042 |  iteration: 6893 teacher: 0 stage: inpainting
# batch 678 loss: 0.86169 acc: 0.73405 | v_loss: 0.86891 v_acc: 0.75651 |  iteration: 6894 teacher: 0 stage: inpainting
# batch 679 loss: 0.90693 acc: 0.73665 | v_loss: 0.77797 v_acc: 0.77539 |  iteration: 6895 teacher: 0 stage: inpainting
# batch 680 loss: 0.29129 acc: 0.91341 | v_loss: 0.89223 v_acc: 0.73958 |  iteration: 6896 teacher: 1 stage: inpainting
# batch 681 loss: 0.86050 acc: 0.74186 | v_loss: 0.83243 v_acc: 0.74251 |  iteration: 6897 teacher: 0 stage: inpainting
# batch 682 loss: 0.30052 acc: 0.91374 | v_loss: 0.79214 v_acc: 0.75684 |  iteration: 6898 teacher: 1 stage: inpainting
# batch 683 loss: 0.88325 acc: 0.73926 | v_loss: 0.86211 v_acc: 0.75065 |  iteration: 6899 teacher: 0 stage: inpainting
# batch 684 loss: 0.29175 acc: 0.90560 | v_loss: 0.84090 v_acc: 0.74219 |  iteration: 6900 teacher: 1 stage: inpainting
# batch 685 loss: 0.25225 acc: 0.92155 | v_loss: 0.83094 v_acc: 0.74674 |  iteration: 6901 teacher: 1 stage: inpainting
# batch 686 loss: 0.86252 acc: 0.74447 | v_loss: 0.82362 v_acc: 0.76595 |  iteration: 6902 teacher: 0 stage: inpainting
# batch 687 loss: 0.26689 acc: 0.91895 | v_loss: 0.70012 v_acc: 0.76302 |  iteration: 6903 teacher: 1 stage: inpainting
# batch 688 loss: 0.30591 acc: 0.90592 | v_loss: 0.73041 v_acc: 0.77083 |  iteration: 6904 teacher: 1 stage: inpainting
# batch 689 loss: 0.81057 acc: 0.74479 | v_loss: 0.80422 v_acc: 0.74544 |  iteration: 6905 teacher: 0 stage: inpainting
# batch 690 loss: 0.27549 acc: 0.91862 | v_loss: 0.83823 v_acc: 0.75000 |  iteration: 6906 teacher: 1 stage: inpainting
# batch 691 loss: 0.84786 acc: 0.74512 | v_loss: 0.84884 v_acc: 0.74544 |  iteration: 6907 teacher: 0 stage: inpainting
# batch 692 loss: 0.83855 acc: 0.74349 | v_loss: 0.75691 v_acc: 0.76302 |  iteration: 6908 teacher: 0 stage: inpainting
# batch 693 loss: 0.95326 acc: 0.72298 | v_loss: 0.84598 v_acc: 0.75098 |  iteration: 6909 teacher: 0 stage: inpainting
# batch 694 loss: 0.29180 acc: 0.91211 | v_loss: 0.83494 v_acc: 0.74479 |  iteration: 6910 teacher: 1 stage: inpainting
# batch 695 loss: 0.88015 acc: 0.73763 | v_loss: 0.79687 v_acc: 0.76465 |  iteration: 6911 teacher: 0 stage: inpainting
# batch 696 loss: 0.26802 acc: 0.91667 | v_loss: 0.70238 v_acc: 0.76888 |  iteration: 6912 teacher: 1 stage: inpainting
# batch 697 loss: 0.34060 acc: 0.90625 | v_loss: 0.68846 v_acc: 0.78516 |  iteration: 6913 teacher: 1 stage: inpainting
# batch 698 loss: 0.27663 acc: 0.91699 | v_loss: 0.73506 v_acc: 0.77539 |  iteration: 6914 teacher: 1 stage: inpainting
# batch 699 loss: 0.91154 acc: 0.74479 | v_loss: 0.76872 v_acc: 0.76107 |  iteration: 6915 teacher: 0 stage: inpainting
# batch 700 loss: 0.94506 acc: 0.73438 | v_loss: 0.81195 v_acc: 0.74740 |  iteration: 6916 teacher: 0 stage: inpainting
# batch 701 loss: 0.28131 acc: 0.91439 | v_loss: 0.77810 v_acc: 0.75684 |  iteration: 6917 teacher: 1 stage: inpainting
# batch 702 loss: 0.27618 acc: 0.91276 | v_loss: 0.79316 v_acc: 0.77246 |  iteration: 6918 teacher: 1 stage: inpainting
# batch 703 loss: 0.80851 acc: 0.75391 | v_loss: 0.88071 v_acc: 0.73405 |  iteration: 6919 teacher: 0 stage: inpainting
# batch 704 loss: 0.27992 acc: 0.91732 | v_loss: 0.90141 v_acc: 0.73958 |  iteration: 6920 teacher: 1 stage: inpainting
# batch 705 loss: 0.28296 acc: 0.91341 | v_loss: 0.81699 v_acc: 0.75684 |  iteration: 6921 teacher: 1 stage: inpainting
# batch 706 loss: 0.85506 acc: 0.74642 | v_loss: 0.82126 v_acc: 0.74609 |  iteration: 6922 teacher: 0 stage: inpainting
# batch 707 loss: 0.82524 acc: 0.74902 | v_loss: 0.69869 v_acc: 0.77181 |  iteration: 6923 teacher: 0 stage: inpainting
# batch 708 loss: 0.85574 acc: 0.75553 | v_loss: 0.80850 v_acc: 0.75618 |  iteration: 6924 teacher: 0 stage: inpainting
# batch 709 loss: 0.29401 acc: 0.91243 | v_loss: 0.79132 v_acc: 0.75814 |  iteration: 6925 teacher: 1 stage: inpainting
# batch 710 loss: 0.28228 acc: 0.91016 | v_loss: 0.84461 v_acc: 0.75130 |  iteration: 6926 teacher: 1 stage: inpainting
# batch 711 loss: 0.38673 acc: 0.90137 | v_loss: 0.80599 v_acc: 0.76107 |  iteration: 6927 teacher: 1 stage: inpainting
# batch 712 loss: 0.24111 acc: 0.92741 | v_loss: 0.80229 v_acc: 0.74772 |  iteration: 6928 teacher: 1 stage: inpainting
# batch 713 loss: 0.89750 acc: 0.73405 | v_loss: 0.78208 v_acc: 0.76204 |  iteration: 6929 teacher: 0 stage: inpainting
# batch 714 loss: 0.85163 acc: 0.75000 | v_loss: 0.74632 v_acc: 0.76790 |  iteration: 6930 teacher: 0 stage: inpainting
# batch 715 loss: 0.96084 acc: 0.72917 | v_loss: 0.93762 v_acc: 0.70964 |  iteration: 6931 teacher: 0 stage: inpainting
# batch 716 loss: 0.86771 acc: 0.73372 | v_loss: 0.77682 v_acc: 0.75195 |  iteration: 6932 teacher: 0 stage: inpainting
# batch 717 loss: 0.92387 acc: 0.73503 | v_loss: 0.81086 v_acc: 0.75814 |  iteration: 6933 teacher: 0 stage: inpainting
# batch 718 loss: 0.28690 acc: 0.91211 | v_loss: 0.71390 v_acc: 0.77930 |  iteration: 6934 teacher: 1 stage: inpainting
# batch 719 loss: 0.85682 acc: 0.74382 | v_loss: 0.77820 v_acc: 0.76074 |  iteration: 6935 teacher: 0 stage: inpainting
# batch 720 loss: 0.84992 acc: 0.74740 | v_loss: 0.72230 v_acc: 0.77409 |  iteration: 6936 teacher: 0 stage: inpainting
# batch 721 loss: 0.28672 acc: 0.91113 | v_loss: 0.84067 v_acc: 0.75781 |  iteration: 6937 teacher: 1 stage: inpainting
# batch 722 loss: 0.77591 acc: 0.76335 | v_loss: 0.80844 v_acc: 0.75293 |  iteration: 6938 teacher: 0 stage: inpainting
# batch 723 loss: 0.81463 acc: 0.75228 | v_loss: 0.91485 v_acc: 0.73210 |  iteration: 6939 teacher: 0 stage: inpainting
# batch 724 loss: 0.87478 acc: 0.73600 | v_loss: 0.83286 v_acc: 0.74642 |  iteration: 6940 teacher: 0 stage: inpainting
# batch 725 loss: 0.87745 acc: 0.74316 | v_loss: 0.83930 v_acc: 0.74382 |  iteration: 6941 teacher: 0 stage: inpainting
# batch 726 loss: 0.30983 acc: 0.90397 | v_loss: 0.85896 v_acc: 0.74284 |  iteration: 6942 teacher: 1 stage: inpainting
# batch 727 loss: 0.90179 acc: 0.73535 | v_loss: 0.80062 v_acc: 0.74967 |  iteration: 6943 teacher: 0 stage: inpainting
# batch 728 loss: 0.81844 acc: 0.75358 | v_loss: 0.87134 v_acc: 0.74219 |  iteration: 6944 teacher: 0 stage: inpainting
# batch 729 loss: 0.30338 acc: 0.91309 | v_loss: 0.75895 v_acc: 0.76270 |  iteration: 6945 teacher: 1 stage: inpainting
# batch 730 loss: 0.82206 acc: 0.75391 | v_loss: 0.79786 v_acc: 0.75098 |  iteration: 6946 teacher: 0 stage: inpainting
# batch 731 loss: 0.30608 acc: 0.90430 | v_loss: 0.77816 v_acc: 0.75553 |  iteration: 6947 teacher: 1 stage: inpainting
# batch 732 loss: 0.84762 acc: 0.74121 | v_loss: 0.73258 v_acc: 0.77409 |  iteration: 6948 teacher: 0 stage: inpainting
# batch 733 loss: 0.84620 acc: 0.74577 | v_loss: 0.69171 v_acc: 0.77441 |  iteration: 6949 teacher: 0 stage: inpainting
# batch 734 loss: 0.82738 acc: 0.75033 | v_loss: 0.86067 v_acc: 0.74707 |  iteration: 6950 teacher: 0 stage: inpainting
# batch 735 loss: 0.95086 acc: 0.73405 | v_loss: 0.94308 v_acc: 0.72266 |  iteration: 6951 teacher: 0 stage: inpainting
# batch 736 loss: 0.84925 acc: 0.73893 | v_loss: 0.79510 v_acc: 0.74023 |  iteration: 6952 teacher: 0 stage: inpainting
# batch 737 loss: 0.25790 acc: 0.91797 | v_loss: 0.85508 v_acc: 0.74512 |  iteration: 6953 teacher: 1 stage: inpainting
# batch 738 loss: 0.28784 acc: 0.91341 | v_loss: 0.74216 v_acc: 0.75488 |  iteration: 6954 teacher: 1 stage: inpainting
# batch 739 loss: 0.27130 acc: 0.92220 | v_loss: 0.79395 v_acc: 0.75065 |  iteration: 6955 teacher: 1 stage: inpainting
# batch 740 loss: 0.88996 acc: 0.73763 | v_loss: 0.69920 v_acc: 0.79004 |  iteration: 6956 teacher: 0 stage: inpainting
# batch 741 loss: 0.82007 acc: 0.75195 | v_loss: 0.74017 v_acc: 0.76074 |  iteration: 6957 teacher: 0 stage: inpainting
# batch 742 loss: 0.22819 acc: 0.92318 | v_loss: 0.88342 v_acc: 0.76497 |  iteration: 6958 teacher: 1 stage: inpainting
# batch 743 loss: 0.23071 acc: 0.92220 | v_loss: 0.71895 v_acc: 0.76107 |  iteration: 6959 teacher: 1 stage: inpainting
# batch 744 loss: 0.80788 acc: 0.75391 | v_loss: 0.82056 v_acc: 0.74577 |  iteration: 6960 teacher: 0 stage: inpainting
# batch 745 loss: 0.27688 acc: 0.91602 | v_loss: 0.77626 v_acc: 0.75391 |  iteration: 6961 teacher: 1 stage: inpainting
# batch 746 loss: 0.29939 acc: 0.91374 | v_loss: 0.73228 v_acc: 0.76530 |  iteration: 6962 teacher: 1 stage: inpainting
# batch 747 loss: 0.86063 acc: 0.74121 | v_loss: 0.86006 v_acc: 0.74609 |  iteration: 6963 teacher: 0 stage: inpainting
# batch 748 loss: 0.86029 acc: 0.74935 | v_loss: 0.79680 v_acc: 0.75195 |  iteration: 6964 teacher: 0 stage: inpainting
# batch 749 loss: 0.84753 acc: 0.74349 | v_loss: 0.73641 v_acc: 0.78190 |  iteration: 6965 teacher: 0 stage: inpainting
# batch 750 loss: 0.26002 acc: 0.91243 | v_loss: 0.82601 v_acc: 0.74512 |  iteration: 6966 teacher: 1 stage: inpainting
# batch 751 loss: 0.32547 acc: 0.90267 | v_loss: 0.74166 v_acc: 0.76432 |  iteration: 6967 teacher: 1 stage: inpainting
# batch 752 loss: 0.28835 acc: 0.90983 | v_loss: 0.92318 v_acc: 0.74349 |  iteration: 6968 teacher: 1 stage: inpainting
# batch 753 loss: 0.24692 acc: 0.91992 | v_loss: 0.77414 v_acc: 0.75749 |  iteration: 6969 teacher: 1 stage: inpainting
# batch 754 loss: 0.27716 acc: 0.91471 | v_loss: 0.82921 v_acc: 0.73796 |  iteration: 6970 teacher: 1 stage: inpainting
# batch 755 loss: 0.29231 acc: 0.91406 | v_loss: 0.78212 v_acc: 0.75293 |  iteration: 6971 teacher: 1 stage: inpainting
# batch 756 loss: 0.30441 acc: 0.90755 | v_loss: 0.85759 v_acc: 0.74284 |  iteration: 6972 teacher: 1 stage: inpainting
# batch 757 loss: 0.25750 acc: 0.91992 | v_loss: 0.74542 v_acc: 0.76432 |  iteration: 6973 teacher: 1 stage: inpainting
# batch 758 loss: 0.90294 acc: 0.73991 | v_loss: 0.77722 v_acc: 0.76758 |  iteration: 6974 teacher: 0 stage: inpainting
# batch 759 loss: 0.90125 acc: 0.74023 | v_loss: 0.75392 v_acc: 0.75586 |  iteration: 6975 teacher: 0 stage: inpainting
# batch 760 loss: 0.89128 acc: 0.73438 | v_loss: 0.99452 v_acc: 0.72298 |  iteration: 6976 teacher: 0 stage: inpainting
# batch 761 loss: 0.84945 acc: 0.74349 | v_loss: 0.75828 v_acc: 0.75033 |  iteration: 6977 teacher: 0 stage: inpainting
# batch 762 loss: 0.26940 acc: 0.91569 | v_loss: 0.85432 v_acc: 0.74479 |  iteration: 6978 teacher: 1 stage: inpainting
# batch 763 loss: 0.88194 acc: 0.73665 | v_loss: 0.79088 v_acc: 0.76270 |  iteration: 6979 teacher: 0 stage: inpainting
# batch 764 loss: 0.24391 acc: 0.92285 | v_loss: 0.86642 v_acc: 0.73372 |  iteration: 6980 teacher: 1 stage: inpainting
# batch 765 loss: 0.81367 acc: 0.74967 | v_loss: 0.82418 v_acc: 0.73633 |  iteration: 6981 teacher: 0 stage: inpainting
# batch 766 loss: 0.88356 acc: 0.73470 | v_loss: 0.89040 v_acc: 0.73470 |  iteration: 6982 teacher: 0 stage: inpainting
# batch 767 loss: 0.84162 acc: 0.74382 | v_loss: 0.86863 v_acc: 0.72917 |  iteration: 6983 teacher: 0 stage: inpainting
# batch 768 loss: 0.88328 acc: 0.73958 | v_loss: 0.76545 v_acc: 0.76107 |  iteration: 6984 teacher: 0 stage: inpainting
# batch 769 loss: 0.87086 acc: 0.74089 | v_loss: 0.86089 v_acc: 0.74577 |  iteration: 6985 teacher: 0 stage: inpainting
# batch 770 loss: 0.88813 acc: 0.73438 | v_loss: 0.77916 v_acc: 0.76725 |  iteration: 6986 teacher: 0 stage: inpainting
# batch 771 loss: 0.94390 acc: 0.73372 | v_loss: 0.89013 v_acc: 0.73340 |  iteration: 6987 teacher: 0 stage: inpainting
# batch 772 loss: 0.90533 acc: 0.73893 | v_loss: 0.82602 v_acc: 0.74740 |  iteration: 6988 teacher: 0 stage: inpainting
# batch 773 loss: 0.85179 acc: 0.74772 | v_loss: 0.78100 v_acc: 0.76497 |  iteration: 6989 teacher: 0 stage: inpainting
# batch 774 loss: 0.31953 acc: 0.90365 | v_loss: 0.84263 v_acc: 0.76335 |  iteration: 6990 teacher: 1 stage: inpainting
